# %% [markdown]
# # Graph set algebra with 🍇🍇 GRAPE 🍇🍇
# Welcome to this tutorial on graph set algebra! In this tutorial, we will learn how to execute set algebraic operations on graphs using [GRAPE!](https://github.com/AnacletoLAB/grape). Such operations can be useful to analyze and describe the structure and relationships of graphs.
#
# We will start by introducing the basic concepts of set theory and set algebra and how they apply to graphs. We will then explore some of the common operations used in set algebra, such as union, intersection, and complement. We will also discuss how to apply these operations to analyze and understand the structure and relationships of different types of graphs.
#
# By the end of this tutorial, you will have a good understanding of how to use set algebra to analyze and describe the structure and relationships of graphs, and you will be able to apply these techniques to your own projects.
#
# [Remember to ⭐ GRAPE!](https://github.com/AnacletoLAB/grape)
#
# ### What is GRAPE?
# [🍇🍇 GRAPE 🍇🍇](https://github.com/AnacletoLAB/grape) is a graph processing and embedding library that enables users to easily manipulate and analyze graphs. With [GRAPE](https://github.com/AnacletoLAB/grape), users can efficiently load and preprocess graphs, generate random walks, and apply various node and edge embedding models. Additionally, [GRAPE](https://github.com/AnacletoLAB/grape) provides a fair and reproducible evaluation pipeline for comparing different graph embedding and graph-based prediction methods.

# %% [markdown]
# ## Set Theory
# [Set theory](https://en.wikipedia.org/wiki/Set_theory) is a branch of mathematics that deals with a set, a collection of objects. Set theory is a foundation of modern mathematics. It can formalize and generalize mathematics concepts such as numbers, functions, and space.
#
# ### The stormy origins of set theory
# The history of set theory can be traced back to ancient Greece, where philosophers such as Zeno of Elea and Euclid used a set to study logical and geometric concepts. However, the modern formulation of set theory began in the late 19th century with the work of Georg Cantor. Cantor developed a theory of infinite sets, which was **a revolutionary idea** at the time because it challenged the traditional mathematical concept of a set as a finite collection of objects.
#
# Initially, set theory was met with resistance from some mathematicians **who believed it was nonsense because it seemed to violate the fundamental principles of mathematics**. For example, the concept of a set containing an infinite number of elements seemed to contradict the principle of one-to-one correspondence, which states that every element in a set has a unique corresponding element in another set. Additionally, set theory introduced the concept of a set having members that could not be determined, which seemed to contradict the principle of definite descriptions, which states that every object has a unique set of properties that can be used to distinguish it from other objects.
#
# Despite this resistance, set theory eventually gained acceptance as a fundamental mathematical concept and became a cornerstone of modern mathematics. **Today, set theory is a fundamental part of the mathematical landscape, and it is used in many areas of mathematics and computer science.**
#
#
# ### Set algebra
# [Set algebra](https://en.wikipedia.org/wiki/Algebra_of_sets) is a branch of mathematics that deals with the manipulation and analysis of sets using algebraic techniques. It is used to describe and reason about sets and their properties using mathematical symbols and operations.
#
# In set algebra, sets are represented by capital letters, and the members of a set are written inside curly braces. For example, the set of all strictly positive integers less than $10$ can be written as $\{1, 2, 3, 4, 5, 6, 7, 8, 9\}$. The **union** of two sets $A$ and $B$ is represented by the symbol $\cup$, and it represents the set of elements that belong to either $A$ or $B$ (or both). The **intersection** of two sets $A$ and $B$ is represented by the symbol $\cap$, and it represents the set of elements that belong to both $A$ and $B$.
#
# Set algebra also includes operations such as **complement**, **difference**, and **power set**.
#
# The **complement** of a set $A$ is the set of elements that *do not belong* to $A$. The difference between two sets $A$ and $B$ is the set of elements that belong to $A$ but not to $B$, and it is represented by the symbol $A - B$ or $A \setminus B$. The power set of a set $A$ is the set of all possible subsets of $A$, and it is represented by the symbol $\mathcal{P}(A)$.
#
# Set algebra is an important tool in many areas of mathematics, including set theory, logic, and computer science. It is used to formalize and analyze sets and their properties, and it is a fundamental part of the mathematical language used to describe and reason about sets.
#
# ### Graphs are sets
# A [graph](https://en.wikipedia.org/wiki/Graph_(discrete_mathematics)) is a mathematical structure used to represent relationships between objects. It consists of a set of nodes (also called vertices) and a set of edges that connect the nodes. The nodes represent the objects, and the edges represent the relationships between the objects.
#
# Graphs are used to model a wide variety of situations and structures, including social networks, transportation systems, and biological systems. They are a useful tool for understanding and analyzing complex systems and relationships.
#
# Graphs are based on the concept of a set, which is a collection of objects. In a graph, the nodes of the graph represent the elements of the set, and the edges represent the relationships between the nodes and form their own set. Set theory provides the mathematical tools for analyzing and manipulating sets, and it is an important foundation for the study of graphs.
#
# Graphs are an important tool in many areas of mathematics and computer science, and they are used to represent and analyze complex structures and relationships. They are a fundamental concept in the study of set theory and discrete mathematics, and they play a central role in many other areas of mathematics and computer science.
#
#
# ### Graph set algebra
# Since graphs are sets, it is possible to readily apply set algebra to graphs. A graph is composed of two sets, so the graph set algebra operations should be designed in a way that maintain consistency between the two sets. This is not always implementative possible or desirable, as we will see shortly.
#
# In the following illustration, I tried to represent graph set algebra using three planar graphs following the [RGB luminosity rules](https://en.wikipedia.org/wiki/RGB_color_model). The red graph represents set $A$, the green graph represents set $B$, and the blue graph represents set $C$. The intersections of the sets are shown in yellow $A \cap B$, purple $A \cap C$, cyan $B \cap C$, and white $A \cap B \cap C$. This figure illustrates how set algebra can be used to analyze and describe the relationships between the nodes and edges of a graph.
#
# <img src="https://github.com/AnacletoLAB/grape/blob/main/images/set_algebra.jpg?raw=true" alt="Graph algebra" width=400 />

# %% [markdown]
# ## Installing GRAPE
# Installing the GRAPE library is super-easy. Just [install it from PyPI](https://pypi.org/project/grape/) as follows:

# %%
# !pip install grape -qU

# %% [markdown]
# ## Hardware requirements
# The following example will use small graphs with up to tens million nodes and edges, so they are small enough you can confidently run them on your notebook without worrying about the memory requirements or the execution time.
#
# Nevertheless, to allow you to easily compare the computer you have access to with what I am currently using, know that I have executed this tutorial on a desktop with 24 threads as 12 cores.

# %%
import os

os.cpu_count()
# Out:
# 24

# %% [markdown]
# ## Experiments
# Welcome to the experiments section of this tutorial! In this section, we will apply various techniques to merge and analyze the five datasets. We will start by merging the HPO and MPO using the union operator, then we will perform an intersection operation between the KGCOVID19 knowledge graph and the union of the HPO and MPO. Next, we will merge the PubMed citation graph with the KGCOVID19 knowledge graph and the HPO and MPO. Finally, we will test the validity of our edge holdouts by checking for overlaps between the training and test sets and by subtracting the test set from the complete Homo Sapiens STRING graph.
#
# By the end of this, you should be a pro at manipulating graphs using graph set algebra.

# %% [markdown]
# ### Datasets
# In this tutorial, we will be working with five datasets: the [Human Phenotype Ontology (HPO)](https://hpo.jax.org/app/), the [Mammalian Phenotype Ontology (MPO)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2801442/), the [STRING protein-protein interaction dataset](https://string-db.org/), [the KGCOVID19 knowledge graph](https://doi.org/10.1016%2Fj.patter.2020.100155), and [the PubMed citation graph](https://github.com/LucaCappelletti94/pubmed_embedding).
#
# The HPO is a standardized vocabulary for describing human phenotypes, used to classify and annotate human phenotypes in a consistent and standardized way. It is an important resource for understanding the underlying causes of human diseases and conditions. The MPO is similar, but for describing the phenotypes of mammals. The STRING dataset is a database of protein-protein interactions in various organisms, represented as a graph. The KGCOVID19 knowledge graph contains information about the COVID-19 pandemic. The PubMed citation graph represents the relationships between articles in the PubMed database, with the nodes of the graph representing articles and the edges representing citations between the articles. The edges can be weighted and labeled with the type of citation.

# %% [markdown]
# ### Human Phenotype Ontology (HPO)
# The [Human Phenotype Ontology (HPO)](https://hpo.jax.org/app/) is a standardized vocabulary for describing human phenotypes, which are the observable characteristics of an individual resulting from the interaction between their genotype and the environment. The HPO is used to classify and annotate human phenotypes in a consistent and standardized way, and it is an important resource for understanding the underlying causes of human diseases and conditions.
#
# The HPO is organized as a hierarchical structure, with each term representing a specific phenotype. The terms are organized into a tree-like structure, with more specific terms being children of more general terms.

# %% [markdown]
# *⚠️ Heads up! This line of code will download a graph! Make sure you have a good internet connection and enough disk space before proceeding! 💾*

# %%
! du -sh /bfd/graphs/kgobo/HP/2022-10-05
# Out:
# 24M	/bfd/graphs/kgobo/HP/2022-10-05

# %%
from grape.datasets.kgobo import HP

hpo = HP(version="2022-10-05")

# %% [markdown]
# Let's check out the report of HPO:

# %%
hpo
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>HP</h2><p class="paragraph">The undirected multigraph HP has 31.67K heterogeneous nodes and 67.84K heterogeneous edges. The graph contains 449 connected components (of which 430 are disconnected nodes), with the largest one containing 16.71K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 3.41MB and 795.96KB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 2.03K, the mode degree is 1, the mean degree is 4.28 and the node degree median is 3.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://amigo.geneontology.org/amigo/term/GO:0065007' target='_blank' title='Go to Gene Ontology to get more informations about GO:0065007'>GO:0065007</a> (degree 2.03K and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a>), <a href='http://purl.obolibrary.org/obo/CARO_0000000' target='_blank' title='Go to Common Anatomy Reference Ontology to get more informations about CARO:0000000'>CARO:0000000</a> (degree 569 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/UBERON_0004120' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0004120'>UBERON:0004120</a> (degree 312 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>), <a href='http://purl.obolibrary.org/obo/UBERON_0010314' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0010314'>UBERON:0010314</a> (degree 271 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>) and <a href='http://purl.obolibrary.org/obo/UBERON_0004121' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0004121'>UBERON:0004121</a> (degree 227 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 12 node types, of which the 10 most common are <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:Phenot ...
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0045083' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045083'>HP:0045083</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.geneontology.org/formats/oboInOwl#logical-definition-view-relation' target='_blank' title='Go to Gene Ontology OBO in OWL to get more informations about OIO:logical-definition-view-relation'>OIO:logical-definition-view-relation</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0045009' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045009'>HP:0045009</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0033029' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033029'>HP:0033029</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0045016' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045016'>HP:0045016</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0045013' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045013'>HP:0045013</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008230' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008230'>HP:0008230</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.org/dc/terms/contributor' target='_blank' title='Go to Dublin Core to get more informations about dc:contributor'>dc:contributor</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0011498' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011498'>HP:0011498</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008008' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008008'>HP:0008008</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008005' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008005'>HP:0008005</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008036' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008036'>HP:0008036</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008033' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008033'>HP:0008033</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/HP_0008051' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008051'>HP:0008051</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>)</p></li></ul><p class="paragraph">And other 415 singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 8 node tuples in the graph, involving a total of 16 nodes (0.05%) and 8 edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BSPO_0000098' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000098'>BSPO:0000098</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BSPO_0000102' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000102'>BSPO:0000102</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002321' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002321'>RO:0002321</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002322' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002322'>RO:0002322</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002005' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002005'>RO:0002005</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002134' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002134'>RO:0002134</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000066' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000066'>BFO:0000066</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BFO_0000067' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000067'>BFO:0000067</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_base_of'>OBO:chebi#is_conjugate_base_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_acid_of'>OBO:chebi#is_conjugate_acid_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0003001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003001'>RO:0003001</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0003000' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003000'>RO:0003000</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001019' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001019'>RO:0001019</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001015' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001015'>RO:0001015</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 3 isomorphic node groups in the graph, involving a total of 7 nodes (0.02%) and 37 edges (0.03%), with the largest one involving 3 nodes and 15 edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 3 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0011314' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011314'>UBERON:0011314</a>, <a href='http://purl.obolibrary.org/obo/UBERON_0011313' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011313'>UBERON:0011313</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0011306' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011306'>UBERON:0011306</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 6 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0003952' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0003952'>UBERON:0003952</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0003953' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0003953'>UBERON:0003953</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0013773' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0013773'>UBERON:0013773</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0013772' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0013772'>UBERON:0013772</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected  a single tree in the graph, involving a total of 10 nodes (0.03%) and 18 edges (0.01%).</p><ul class="large-columns"><li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002342' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002342'>RO:0002342</a> (degree 2), and containing 10 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/RO_0002021' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002021'>RO:0002021</a>, <a href='http://purl.obolibrary.org/obo/RO_0002344' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002344'>RO:0002344</a> (degree 4), <a href='http://purl.obolibrary.org/obo/RO_0002479' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002479'>RO:0002479</a> (degree 3), <a href='http://purl.obolibrary.org/obo/RO_0002338' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002338'>RO:0002338</a> and <a href='http://purl.obolibrary.org/obo/RO_0002339' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002339'>RO:0002339</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 557 dendritic trees in the graph, involving a total of 8.57K nodes (27.08%) and 17.15K edges (12.64%), with the largest one involving 245 nodes and 490 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0002960' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002960'>HP:0002960</a> (degree 8), and containing 245 nodes, with a maximal depth of 5, which are <a href='http://purl.obolibrary.org/obo/HP_0030057' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030057'>HP:0030057</a> (degree 162), <a href='http://purl.obolibrary.org/obo/HP_0032265' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032265'>HP:0032265</a>, <a href='http://purl.obolibrary.org/obo/HP_0002725' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002725'>HP:0002725</a>, <a href='http://purl.obolibrary.org/obo/HP_0033030' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033030'>HP:0033030</a> and <a href='http://purl.obolib ...
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000504' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000504'>HP:0000504</a> (degree 16), and containing 131 nodes, with a maximal depth of 6, which are <a href='http://purl.obolibrary.org/obo/HP_0011514' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011514'>HP:0011514</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0030786' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030786'>HP:0030786</a>, <a href='http://purl.obolibrary.org/obo/HP_0025152' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025152'>HP:0025152</a>, <a href='http://purl.obolibrary.org/obo/HP_0030511' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030511'>HP:0030511</a> and <a href='http://purl.obolibrary.org/obo/HP_0030512' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030512'>HP:0030512</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0012823' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012823'>HP:0012823</a> (degree 13), and containing 128 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/HP_0045088' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045088'>HP:0045088</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0025254' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025254'>HP:0025254</a> (degree 7), <a href='http://purl.obolibrary.org/obo/HP_0025280' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025280'>HP:0025280</a> (degree 5), <a href='http://purl.obolibrary.org/obo/HP_0025285' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025285'>HP:0025285</a> (degree 10) and <a href='http://purl.obolibrary.org/obo/HP_0025204' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025204'>HP:0025204</a> (degree 25). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0033354' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033354'>HP:0033354</a> (degree 44), and containing 123 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/HP_0011814' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011814'>HP:0011814</a>, <a href='http://purl.obolibrary.org/obo/HP_0033187' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033187'>HP:0033187</a>, <a href='http://purl.obolibrary.org/obo/HP_0033594' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033594'>HP:0033594</a>, <a href='http://purl.obolibrary.org/obo/HP_0011942' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011942'>HP:0011942</a> and <a href='http://purl.obolibrary.org/obo/HP_0011943' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011943'>HP:0011943</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0010876' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010876'>HP:0010876</a> (degree 55), and containing 117 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/HP_0033103' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033103'>HP:0033103</a>, <a href='http://purl.obolibrary.org/obo/HP_0033115' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033115'>HP:0033115</a>, <a href='http://purl.obolibrary.org/obo/HP_0045056' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0045056'>HP:0045056</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0033123' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033123'>HP:0033123</a> and <a href='http://purl.obolibrary.org/obo/HP_0033144' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033144'>HP:0033144</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0011805' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011805'>HP:0011805</a> (degree 44), and containing 105 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/HP_0410169' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0410169'>HP:0410169</a>, <a href='http://purl.obolibrary.org/obo/HP_0410168' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0410168'>HP:0410168</a>, <a href='http://purl.obolibrary.org/obo/HP_0410167' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0410167'>HP:0410167</a>, <a href='http://purl.obolibrary.org/obo/HP_0025718' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025718'>HP:0025718</a> and <a href='http://purl.obolibrary.org/obo/HP_0040291' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0040291'>HP:0040291</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 551 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected  a single star in the graph, involving a total of 3 nodes and 4 edges.</p><ul class="large-columns"><li><p class="paragraph">Star starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0015006' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015006'>RO:0015006</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/RO_0015007' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015007'>RO:0015007</a> and <a href='http://purl.obolibrary.org/obo/RO_0015008' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015008'>RO:0015008</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 680 dendritic stars in the graph, involving a total of 2.20K nodes (6.95%) and 4.40K edges (3.25%), with the largest one involving 17 nodes and 34 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001028' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001028'>HP:0001028</a> (degree 26), and containing 17 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0410269' target='_bl ...
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001878' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001878'>HP:0001878</a> (degree 17), and containing 15 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0008269' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008269'>HP:0008269</a>, <a href='http://purl.obolibrary.org/obo/HP_0001937' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001937'>HP:0001937</a>, <a href='http://purl.obolibrary.org/obo/HP_0001930' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001930'>HP:0001930</a>, <a href='http://purl.obolibrary.org/obo/HP_0005525' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005525'>HP:0005525</a> and <a href='http://purl.obolibrary.org/obo/HP_0005524' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005524'>HP:0005524</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MAXO_0000665' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000665'>OBO:MAXO_0000665</a> (degree 26), and containing 13 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MAXO_0000699' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000699'>OBO:MAXO_0000699</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000697' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000697'>OBO:MAXO_0000697</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000698' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000698'>OBO:MAXO_0000698</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000666' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000666'>OBO:MAXO_0000666</a> and <a href='http://purl.obolibrary.org/obo/MAXO_0000670' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000670'>OBO:MAXO_0000670</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MAXO_0000680' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000680'>OBO:MAXO_0000680</a> (degree 16), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MAXO_0000691' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000691'>OBO:MAXO_0000691</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000692' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000692'>OBO:MAXO_0000692</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000690' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000690'>OBO:MAXO_0000690</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000693' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000693'>OBO:MAXO_0000693</a> and <a href='http://purl.obolibrary.org/obo/MAXO_0000694' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000694'>OBO:MAXO_0000694</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001770' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001770'>HP:0001770</a> (degree 14), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0001459' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001459'>HP:0001459</a>, <a href='http://purl.obolibrary.org/obo/HP_0010717' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010717'>HP:0010717</a>, <a href='http://purl.obolibrary.org/obo/HP_0010716' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010716'>HP:0010716</a>, <a href='http://purl.obolibrary.org/obo/HP_0010715' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010715'>HP:0010715</a> and <a href='http://purl.obolibrary.org/obo/HP_0010714' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010714'>HP:0010714</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0011038' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011038'>HP:0011038</a> (degree 13), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0008666' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008666'>HP:0008666</a>, <a href='http://purl.obolibrary.org/obo/HP_0005579' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005579'>HP:0005579</a>, <a href='http://purl.obolibrary.org/obo/HP_0005571' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005571'>HP:0005571</a>, <a href='http://purl.obolibrary.org/obo/HP_0034357' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0034357'>HP:0034357</a> and <a href='http://purl.obolibrary.org/obo/HP_0034356' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0034356'>HP:0034356</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 674 dendritic stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic tendril stars</h4><p class="paragraph">A dendritic tendril star is a dendritic tree with a depth greater than one, where the arms of the star are tendrils. We have detected 136 dendritic tendril stars in the graph, involving a total of 691 nodes (2.18%) and 1.38K edges (1.02%), with the largest one involving 13 nodes and 26 edges. The detected dendritic tendril stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/PATO_0000052' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0000052'>PATO:0000052</a> (degree 26), and containing 13 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/PATO_0001481' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001481'>PATO:0001481</a>, <a href='http://purl.obolibrary.org/obo/PATO_0001977' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001977'>PATO:0001977</a>, <a href='http://purl.obolibrary.org/obo/PATO_0001878' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001878'>PATO:0001878</a>, <a href='http://purl.obolibrary.org/obo/PATO_0002212' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0002212'>PATO:0002212</a> and <a href='http://purl.obolibrary.org/obo/PATO_0002180' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0002180'>PATO:0002180</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0002031' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002031'>HP:0002031</a> (degree 19), and containing 12 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0011128' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011128'>HP:0011128</a>, <a href='http://purl.obolibrary.org/obo/HP_0005203' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005203'>HP:0005203</a>, <a href='http://purl.obolibrary.org/obo/HP_0010450' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010450'>HP:0010450</a>, <a href='http://purl.obolibrary.org/obo/HP_0012859' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012859'>HP:0012859</a> and <a href='http://purl.obolibrary.org/obo/HP_0032062' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032062'>HP:0032062</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0031331' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031331'>HP:0031331</a> (degree 12), and containing 11 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0031319' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031319'>HP:0031319</a>, <a href='http://purl.obolibrary.org/obo/HP_0031320' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031320'>HP:0031320</a>, <a href='http://purl.obolibrary.org/obo/HP_0031332' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031332'>HP:0031332</a>, <a href='http://purl.obolibrary.org/obo/HP_0031333' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031333'>HP:0031333</a> and <a href='http://purl.obolibrary.org/obo/HP_0031334' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031334'>HP:0031334</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0003170' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003170'>HP:0003170</a> (degree 11), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0033640' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033640'>HP:0033640</a>, <a href='http://purl.obolibrary.org/obo/HP_0003274' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003274'>HP:0003274</a>, <a href='http://purl.obolibrary.org/obo/HP_0003182' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003182'>HP:0003182</a>, <a href='http://purl.obolibrary.org/obo/HP_0003180' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003180'>HP:0003180</a> and <a href='http://purl.obolibrary.org/obo/HP_0003179' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003179'>HP:0003179</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0012440' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012440'>HP:0012440</a> (degree 14), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0001408' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001408'>HP:0001408</a>, <a href='http://purl.obolibrary.org/obo/HP_0030986' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030986'>HP:0030986</a>, <a href='http://purl.obolibrary.org/obo/HP_0025154' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025154'>HP:0025154</a>, <a href='http://purl.obolibrary.org/obo/HP_0005230' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005230'>HP:0005230</a> and <a href='http://purl.obolibrary.org/obo/HP_0034352' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0034352'>HP:0034352</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MAXO_0001238' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001238'>OBO:MAXO_0001238</a> (degree 11), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MAXO_0001239' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001239'>OBO:MAXO_0001239</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0001242' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001242'>OBO:MAXO_0001242</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0001241' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001241'>OBO:MAXO_0001241</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0001240' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001240'>OBO:MAXO_0001240</a> and <a href='http://purl.obolibrary.org/obo/MAXO_0001246' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0001246'>OBO:MAXO_0001246</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 130 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Free-floating chains</h4><p class="paragraph">A free-floating chain is a tree with maximal degree two. We have detected  a single free-floating chain in the graph, involving a total of 4 nodes (0.01%) and 6 edges.</p><ul class="large-columns"><li><p class="paragraph">Free-floating chain starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002563' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002563'>RO:0002563</a> (degree 2), and containing 4 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/RO_0002464' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002464'>RO:0002464</a>, <a href='http://purl.obolibrary.org/obo/RO_0002564' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002564'>RO:0002564</a> and <a href='http://purl.obolibrary.org/obo/RO_0002481' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002481'>RO:0002481</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 681 tendrils in the graph, involving a total of 768 nodes (2.43%) and 1.54K edges (1.13%), with the largest one involving 8 nodes and 16 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8457' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8457'>NCBITaxon:8457</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which a ...
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6231' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6231'>NCBITaxon:6231</a> (degree 3), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=119089' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:119089'>NCBITaxon:119089</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6236' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6236'>NCBITaxon:6236</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301116' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301116'>NCBITaxon:2301116</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301119' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301119'>NCBITaxon:2301119</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=55879' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:55879'>NCBITaxon:55879</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4890' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4890'>NCBITaxon:4890</a> (degree 3), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=451866' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:451866'>NCBITaxon:451866</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=147554' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:147554'>NCBITaxon:147554</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=34346' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:34346'>NCBITaxon:34346</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4894' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4894'>NCBITaxon:4894</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4895' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4895'>NCBITaxon:4895</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=147537' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:147537'>NCBITaxon:147537</a> (degree 3), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4891' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4891'>NCBITaxon:4891</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4892' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4892'>NCBITaxon:4892</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4893' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4893'>NCBITaxon:4893</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4930' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4930'>NCBITaxon:4930</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4932' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4932'>NCBITaxon:4932</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:63299' target='_blank' title='Go to CHEBI to get more informations about CHEBI:63299'>CHEBI:63299</a> (degree 17), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:63161' target='_blank' title='Go to CHEBI to get more informations about CHEBI:63161'>CHEBI:63161</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24400' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24400'>CHEBI:24400</a>, <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:35313' target='_blank' title='Go to CHEBI to get more informations about CHEBI:35313'>CHEBI:35313</a> and <a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24163' target='_blank' title='Go to CHEBI to get more informations about CHEBI:24163'>CHEBI:24163</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=142796' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:142796'>NCBITaxon:142796</a> (degree 3), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33083' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33083'>NCBITaxon:33083</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2058949' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2058949'>NCBITaxon:2058949</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2058185' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2058185'>NCBITaxon:2058185</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=5782' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:5782'>NCBITaxon:5782</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 675 tendrils.</p></div>

# %% [markdown]
# ### Mammalian Phenotype Ontology
# The [Mammalian Phenotype Ontology (MPO)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2801442/) is a standardized vocabulary for describing the phenotypes of mammals. Like the Human Phenotype Ontology (HPO), the MPO is used to classify and annotate the phenotypes of mammals in a consistent and standardized way, and it is an important resource for understanding the underlying causes of diseases and conditions in mammals.
#
# Like HPO, MPO is also organized as a hierarchical structure, with each term representing a specific phenotype. The terms are organized into a tree-like structure, with more specific terms being children of more general terms.

# %% [markdown]
# *⚠️ Heads up! This line of code will download a graph! Make sure you have a good internet connection and enough disk space before proceeding! 💾*

# %%
! du -sh /bfd/graphs/kgobo/MP/2021-11-04
# Out:
# 14M	/bfd/graphs/kgobo/MP/2021-11-04

# %%
from grape.datasets.kgobo import MP

mpo = MP(version="2021-11-04")

# %% [markdown]
# Let's checkout the report of MPO:

# %%
mpo
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>MP</h2><p class="paragraph">The undirected graph MP has 27.75K homogeneous nodes and 30.40K heterogeneous edges. The graph contains 4.55K connected components (of which 4.55K are disconnected nodes), with the largest one containing 23.20K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 3.35MB and 465.29KB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 1.28K, the mode degree is 1, the mean degree is 2.19 and the node degree median is 1.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://orcid.org/0000-0002-6490-7723' target='_blank' title='Go to website to get more informations about http:&#x2f;&#x2f;orcid.org&#x2f;0000-0002-6490-7723'>http:&#x2f;&#x2f;orcid.org&#x2f;0000-0002-6490-7723</a> (degree 1.28K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/mp-edit#IMPC' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp-edit#IMPC'>OBO:mp-edit#IMPC</a> (degree 624 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://orcid.org/0000-0003-4606-0597' target='_blank' title='Go to website to get more informations about http:&#x2f;&#x2f;orcid.org&#x2f;0000-0003-4606-0597'>http:&#x2f;&#x2f;orcid.org&#x2f;0000-0003-4606-0597</a> (degree 558 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/mp-edit#Sanger_Terms' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp-edit#Sanger_Terms'>OBO:mp-edit#Sanger_Terms</a> (degree 464 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/mp-edit#Europhenome_Terms' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp-edit#Europhenome_Terms'>OBO:mp-edit#Europhenome_Terms</a> (degree 354 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more  ...
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0002314' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002314'>RO:0002314</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/BFO_0000051' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000051'>BFO:0000051</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0000052' target='_blank' title='Go to Relation Ontology to get more informations about RO:0000052'>RO:0000052</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0002503' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002503'>RO:0002503</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/mp/mp-equivalent-axioms-subq#results_from' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp&#x2f;mp-equivalent-axioms-subq#results_from'>OBO:mp&#x2f;mp-equivalent-axioms-subq#results_from</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/mp/mp-equivalent-axioms-subq#preceded_by' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp&#x2f;mp-equivalent-axioms-subq#preceded_by'>OBO:mp&#x2f;mp-equivalent-axioms-subq#preceded_by</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/BFO_0000050' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000050'>BFO:0000050</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0002573' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002573'>RO:0002573</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0000087' target='_blank' title='Go to Relation Ontology to get more informations about RO:0000087'>RO:0000087</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/BFO_0000066' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000066'>BFO:0000066</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/mpath#part_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mpath#part_of'>OBO:mpath#part_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/mp/mp-equivalent-axioms-subq#has_quality' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp&#x2f;mp-equivalent-axioms-subq#has_quality'>OBO:mp&#x2f;mp-equivalent-axioms-subq#has_quality</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://purl.obolibrary.org/obo/RO_0002296' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002296'>RO:0002296</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li></ul><p class="paragraph">And other 4.54K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 849 dendritic trees in the graph, involving a total of 9.85K nodes (35.51%) and 19.71K edges (32.41%), with the largest one involving 188 nodes and 376 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0005584' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005584'>MP:0005584</a> (degree 44), and containing 188 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/MP_0012640' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012640'>MP:0012640</a> (degree 3), <a href='http://purl.obolibrary.org/obo/MP_0011583' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011583'>MP:0011583</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0020051' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020051'>MP:0020051</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0020227' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020227'>MP:0020227</a> (degree 4) and <a href='http://purl.obolibrary.org/obo/MP_0011598' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011598'>MP:0011598</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (207 edges, 61.24%) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (131 edges, 38.76%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0003009' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0003009'>MP:0003009</a> (degree 7), and containing 160 nodes, with a maximal depth of 5, which are <a href='http://purl.obolibrary.org/obo/MP_0008568' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008568'>MP:0008568</a> (degree 20), <a href='http://purl.obolibrary.org/obo/MP_0008556' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008556'>MP:0008556</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008555' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008555'>MP:0008555</a> (degree 4), N764086610974445e976b96248ef33097 and <a href='http://purl.obolibrary.org/obo/MP_0008680' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008680'>MP:0008680</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (163 edges, 51.58%) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (153 edges, 48.42%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0008588' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008588'>MP:0008588</a> (degree 21), and containing 134 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/MP_0008625' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008625'>MP:0008625</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008590' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008590'>MP:0008590</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008604' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008604'>MP:0008604</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008589' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008589'>MP:0008589</a> (degree 6) and <a href='http://purl.obolibrary.org/obo/MP_0008598' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008598'>MP:0008598</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (134 edges, 53.82%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (115 edges, 46.18%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0009643' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0009643'>MP:0009643</a> (degree 40), and containing 93 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/MP_0011465' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011465'>MP:0011465</a> (degree 3), <a href='http://purl.obolibrary.org/obo/MP_0002900' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002900'>MP:0002900</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0002987' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002987'>MP:0002987</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0011740' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011740'>MP:0011740</a> (degree 4) and <a href='http://purl.obolibrary.org/obo/MP_0009471' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0009471'>MP:0009471</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (83 edges, 51.55%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (78 edges, 48.45%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0004163' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004163'>MP:0004163</a> (degree 14), and containing 87 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/MP_0008327' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008327'>MP:0008327</a> (degree 6), <a href='http://purl.obolibrary.org/obo/MP_0008325' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008325'>MP:0008325</a> (degree 6), <a href='http://purl.obolibrary.org/obo/MP_0008323' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008323'>MP:0008323</a> (degree 6), <a href='http://purl.obolibrary.org/obo/MP_0008326' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008326'>MP:0008326</a> (degree 6) and <a href='http://purl.obolibrary.org/obo/MP_0008321' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008321'>MP:0008321</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (87 edges, 53.37%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (76 edges, 46.63%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0002085' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002085'>MP:0002085</a> (degree 37), and containing 71 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/MP_0013230' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013230'>MP:0013230</a>, <a href='http://purl.obolibrary.org/obo/MP_0003988' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0003988'>MP:0003988</a>, <a href='http://purl.obolibrary.org/obo/MP_0011835' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011835'>MP:0011835</a>, <a href='http://purl.obolibrary.org/obo/MP_0002825' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002825'>MP:0002825</a> (degree 8) and <a href='http://purl.obolibrary.org/obo/MP_0010115' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0010115'>MP:0010115</a> (degree 7). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (69 edges, 56.10%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (54 edges, 43.90%).</p></li></ol><p class="paragraph">And other 843 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 186 dendritic stars in the graph, involving a total of 462 nodes (1.66%) and 924 edges (1.52%), with the largest one involving 8 nodes and 16 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0013118' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013118'>MP:0013118</a> (degree 10), and containing 8 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0013120' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013120'>MP:0013120</a>, <a href='http://purl.obolibrary.org/obo/MP_0013126' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013126'>MP:0013126</a>, <a href='http://purl.obolibrary.org/obo/MP_0013123' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013123'>MP:0013123</a>, <a href='http://purl.obolibrary.org/obo/MP_0013119' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013119'>MP:0013119</a> and <a href='http://purl.obolibrary.org/obo/MP_0013121' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013121'>MP:0013121</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get m ...
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0005351' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005351'>MP:0005351</a> (degree 10), and containing 7 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0004822' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004822'>MP:0004822</a>, <a href='http://purl.obolibrary.org/obo/MP_0004800' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004800'>MP:0004800</a>, <a href='http://purl.obolibrary.org/obo/MP_0004802' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004802'>MP:0004802</a>, <a href='http://purl.obolibrary.org/obo/MP_0004826' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004826'>MP:0004826</a> and <a href='http://purl.obolibrary.org/obo/MP_0004804' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004804'>MP:0004804</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0005350' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005350'>MP:0005350</a> (degree 10), and containing 7 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0004823' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004823'>MP:0004823</a>, <a href='http://purl.obolibrary.org/obo/MP_0004799' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004799'>MP:0004799</a>, <a href='http://purl.obolibrary.org/obo/MP_0012567' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012567'>MP:0012567</a>, <a href='http://purl.obolibrary.org/obo/MP_0004825' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004825'>MP:0004825</a> and <a href='http://purl.obolibrary.org/obo/MP_0004803' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004803'>MP:0004803</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0014062' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014062'>MP:0014062</a> (degree 11), and containing 6 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0008493' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008493'>MP:0008493</a>, <a href='http://purl.obolibrary.org/obo/MP_0014063' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014063'>MP:0014063</a>, <a href='http://purl.obolibrary.org/obo/MP_0014067' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014067'>MP:0014067</a>, <a href='http://purl.obolibrary.org/obo/MP_0014066' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014066'>MP:0014066</a> and <a href='http://purl.obolibrary.org/obo/MP_0014065' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014065'>MP:0014065</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0001942' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001942'>MP:0001942</a> (degree 10), and containing 6 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0002311' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002311'>MP:0002311</a>, <a href='http://purl.obolibrary.org/obo/MP_0002312' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002312'>MP:0002312</a>, N4dafb72d42cd4cb6a5614e4483ff2dec, <a href='http://purl.obolibrary.org/obo/MP_0002306' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002306'>MP:0002306</a> and <a href='http://purl.obolibrary.org/obo/MP_0002309' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0002309'>MP:0002309</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0005221' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005221'>MP:0005221</a> (degree 7), and containing 5 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MP_0012156' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012156'>MP:0012156</a>, N6f71c147d6e541c88800aa1c6a8cbdc8, <a href='http://purl.obolibrary.org/obo/MP_0012157' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012157'>MP:0012157</a>, <a href='http://purl.obolibrary.org/obo/MP_0012173' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012173'>MP:0012173</a> and <a href='http://purl.obolibrary.org/obo/MP_0004073' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004073'>MP:0004073</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (4 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a>.</p></li></ol><p class="paragraph">And other 180 dendritic stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic tendril stars</h4><p class="paragraph">A dendritic tendril star is a dendritic tree with a depth greater than one, where the arms of the star are tendrils. We have detected 421 dendritic tendril stars in the graph, involving a total of 1.35K nodes (4.86%) and 2.70K edges (4.43%), with the largest one involving 7 nodes and 14 edges. The detected dendritic tendril stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0001516' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001516'>MP:0001516</a> (degree 17), and containing 7 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0001401' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001401'>MP:0001401</a>, <a href='http://purl.obolibrary.org/obo/MP_0005424' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005424'>MP:0005424</a>, <a href='http://purl.obolibrary.org/obo/MP_0001525' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001525'>MP:0001525</a>, N2cd5c9914c91438daf21f087ef2b1c27 and <a href='http://purl.obolibrary.org/obo/MP_0001526' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001526'>MP:0001526</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (3 edges).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0004264' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004264'>MP:0004264</a> (degree 14), and containing 7 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0012120' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012120'>MP:0012120</a>, <a href='http://purl.obolibrary.org/obo/MP_0004076' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004076'>MP:0004076</a>, <a href='http://purl.obolibrary.org/obo/MP_0001724' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0001724'>MP:0001724</a>, <a href='http://purl.obolibrary.org/obo/MP_0004558' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004558'>MP:0004558</a> and N0080c2d6b1b6495c9292c62ada11ce2c. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (3 edges).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0003491' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0003491'>MP:0003491</a> (degree 10), and containing 7 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/MP_0012051' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012051'>MP:0012051</a>, <a href='http://purl.obolibrary.org/obo/MP_0020211' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020211'>MP:0020211</a>, <a href='http://purl.obolibrary.org/obo/MP_0012343' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012343'>MP:0012343</a>, <a href='http://purl.obolibrary.org/obo/MP_0012344' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012344'>MP:0012344</a> and Nc136f357d5cf4143af9f5680d7511bb8. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (8 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0011513' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011513'>MP:0011513</a> (degree 8), and containing 7 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0013914' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013914'>MP:0013914</a>, <a href='http://purl.obolibrary.org/obo/MP_0014002' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014002'>MP:0014002</a>, <a href='http://purl.obolibrary.org/obo/MP_0014001' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014001'>MP:0014001</a>, <a href='http://purl.obolibrary.org/obo/MP_0013996' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013996'>MP:0013996</a> and <a href='http://purl.obolibrary.org/obo/MP_0014003' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0014003'>MP:0014003</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (3 edges).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0004844' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004844'>MP:0004844</a> (degree 8), and containing 7 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0004845' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0004845'>MP:0004845</a>, <a href='http://purl.obolibrary.org/obo/MP_0011042' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011042'>MP:0011042</a>, <a href='http://purl.obolibrary.org/obo/MP_0011041' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011041'>MP:0011041</a>, <a href='http://purl.obolibrary.org/obo/MP_0011039' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011039'>MP:0011039</a> and <a href='http://purl.obolibrary.org/obo/MP_0011040' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011040'>MP:0011040</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (3 edges).</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0012730' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012730'>MP:0012730</a> (degree 8), and containing 7 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0013870' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013870'>MP:0013870</a>, <a href='http://purl.obolibrary.org/obo/MP_0013998' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013998'>MP:0013998</a>, <a href='http://purl.obolibrary.org/obo/MP_0013999' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013999'>MP:0013999</a>, <a href='http://purl.obolibrary.org/obo/MP_0013997' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0013997'>MP:0013997</a> and N22132511a64245bb926ae3b80c2dc8f2. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (5 edges) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (3 edges).</p></li></ol><p class="paragraph">And other 415 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 4.16K tendrils in the graph, involving a total of 4.18K nodes (15.05%) and 8.35K edges (13.74%). The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0021002' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0021002'>MP:0021002</a> (degree 7), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0008025' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008025'>MP:0008025</a> and N4fc9b3cb9641454a91dd2b9638c614b2. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (2 edges) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0010274' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0010274'>MP:0010274</a> (degree 16), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0020199' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020199'>MP:0020199</a> and <a href='http://purl.obolibrary.org/obo/MP_0020200' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020200'>MP:0020200</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0010768' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0010768'>MP:0010768</a> (degree 5), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0011614' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011614'>MP:0011614</a> and N96b8ddfa5f9649a48a9824a197b789ad. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (2 edges) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0010346' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0010346'>MP:0010346</a> (degree 3), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0010345' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0010345'>MP:0010345</a> and Ne3e592e30613470daa17e3333d0b4dee. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (2 edges) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0009669' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0009669'>MP:0009669</a> (degree 4), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0009670' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0009670'>MP:0009670</a> and <a href='http://purl.obolibrary.org/obo/MP_0012727' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012727'>MP:0012727</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0020147' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0020147'>MP:0020147</a> (degree 3), and containing 2 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MP_0012311' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0012311'>MP:0012311</a> and Nb122372b37d5431a8dee41b712207e0a. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (2 edges) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 4.16K tendrils.</p></div>

# %% [markdown]
# ### STRING protein-protein interaction
# [STRING (Search Tool for the Retrieval of Interacting Genes/Proteins)](https://string-db.org/) is a database that provides information on protein-protein interactions (PPIs) in a variety of organisms. The database includes a large network of PPIs, which is represented as a graph.
#
# In the STRING graph, the nodes represent proteins, and the edges represent the interactions between the proteins. The edges are weighted to indicate the confidence in the existance of the interaction, and goes from `100` to `1000`. It is generally filtered at `700`, as we will see shortly.

# %%
# %%time
from grape.datasets.string import HomoSapiens

homo_sapiens = HomoSapiens()
# Out:
# CPU times: user 14.4 s, sys: 652 ms, total: 15 s
# Wall time: 8.61 s

# %% [markdown]
# Let's take a look at STRING's graph report:

# %%
homo_sapiens
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>HomoSapiens</h2><p class="paragraph">The undirected graph HomoSapiens has 19.57K heterogeneous nodes and 5.97M edges. The graph contains 182 connected components (of which 181 are disconnected nodes), with the largest one containing 19.39K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 2.67MB and 47.91MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 7.51K, the mode degree is 0, the mean degree is 610.17 and the node degree median is 485.</p><p class="paragraph">The nodes with the highest degree centrality are 9606.ENSP00000229239 (degree 7.51K and node types BTO:0000000, BTO:0000007, BTO:0000020, BTO:0000032, BTO:0000035 and other 554), 9606.ENSP00000349960 (degree 6.94K and node types BTO:0000000, BTO:0000007, BTO:0000020, BTO:0000042, BTO:0000058 and other 696), 9606.ENSP00000451828 (degree 5.92K and node types BTO:0000000, BTO:0000003, BTO:0000018, BTO:0000042, BTO:0000047 and other 1.37K), 9606.ENSP00000298910 (degree 5.80K and node types BTO:0000000, BTO:0000042, BTO:0000138, BTO:0000142, BTO:0000143 and other 984) and 9606.ENSP00000269305 (degree 5.65K and node types BTO:0000000, BTO:0000003, BTO:0000018, BTO:0000042, BTO:0000058 and other 1.35K).</p><h3 style="margin: 1em 0 0 0;">Weights</h3><p class="paragraph">The minimum edge weight is 150, the maximum edge weight is 999 and the total edge weight is 3342953700. The RAM requirement for the edge weights data structure is 47.75MB.</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 62.23K node types, of which the 10 most common are GO:0110165 (17.79K nodes, 90.91%), GO:0009987 (15.02K nodes, 76.79%), BTO:0000000 (14.94K nodes, 76.37%), BTO:0000042 (14.89K nodes, 76.13%), GO:0005622 (14.28K nodes, 72.96%), GOCC:0110165 (13.85K nodes, 70.80%), GO:0043226 (13.52K nodes, 69.07%), BTO:0001489 (12.62K nodes, 64.49%), GO:0043229 (12.53K nodes, 64.03%) and GO:0005488 (12.52K nodes, 63.97%). The node types are multi-label, and the node with most node types has 1379 node types. The RAM requirement for the node types data structure is 19.13MB.</p><h4 style="margin: 1em 0 0 0;">Approximated isomorphic node types</h4><p class="paragraph">Approximated isomorphic node types groups are node types describing exactly the same set of nodes. Since the graph has a high number of node types (> 50.00K) we use an approximated version of the node types isomorphisms detection. Note that hash collisions and false positives are possible. It is possible to execute the exact computation with the <code>get_isomorphic_node_type_ids_groups</code> method. The presence of such duplicated node types suggests a potential modelling error in the pipeline that has produced this graph. 9.34K isomorphic node types groups were detected in this graph.</p><ol><li><p class="paragraph">Isomorphic node type group containing 3 node types (5.86K nodes, 2 ...
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (3.06K nodes, 15.65%), which are: GO:0006464 and GO:0036211.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (2.82K nodes, 14.39%), which are: GOCC:0031974 and GOCC:0043233.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.45K nodes, 7.43%), which are: GO:0038023 and GO:0060089.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.21K nodes, 6.20%), which are: GO:0031967 and GO:0031975.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.16K nodes, 5.95%), which are: GO:0010562 and GO:0045937.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.02K nodes, 5.20%), which are: GO:0048870 and GO:0051674.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (814 nodes, 4.16%), which are: GO:0016817 and GO:0016818.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (698 nodes, 3.57%), which are: GO:0000323 and GO:0005764.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (648 nodes, 3.31%), which are: BTO:0000775 and BTO:0001096.</p></li></ol><p class="paragraph">And other 9.33K isomorphic node types.</p><h4 style="margin: 1em 0 0 0;">Singleton node types</h4><p class="paragraph">Singleton node types are node types that are assigned exclusively to a single node, making the node type relatively meaningless, as it adds no more information than the node name itself. The graph contains 16.85K singleton node types, which are IPR028927 (9606.ENSP00000000412 (degree 480 and node types BTO:0000000, BTO:0000042, BTO:0000080, BTO:0000081, BTO:0000082 and other 188)), GO:0006463 (9606.ENSP00000001008 (degree 1.70K and node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR031212 (9606.ENSP00000001008 (degree 1.70K and node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR003788 (9606.ENSP00000002125 (degree 357 and node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), IPR038375 (9606.ENSP00000002125 (degree 357 and node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), PF02636 (9606.ENSP00000002125 (degree 357 and node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), BTO:0001193 (9606.ENSP00000003084 (degree 1.91K and node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002032 (9606.ENSP00000003084 (degree 1.91K and node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002750 (9606.ENSP00000003084 (degree 1.91K and node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)) and BTO:0004445 (9606.ENSP00000003084 (degree 1.91K and node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), plus other 16.84K singleton node types.</p><h4 style="margin: 1em 0 0 0;">Unknown node types</h4><p class="paragraph">Nodes with unknown node types are nodes with a node type that was not provided during the creation of the graph, which may be desired as the output of a node-label holdout. The graph contains 159 nodes with unknown node type, which are 9606.ENSP00000239125 (degree 1), 9606.ENSP00000278779, 9606.ENSP00000303234 (degree 1), 9606.ENSP00000326574 (degree 2), 9606.ENSP00000362001, 9606.ENSP00000365108, 9606.ENSP00000366765, 9606.ENSP00000367360, 9606.ENSP00000367983 and 9606.ENSP00000368055, plus other 149 nodes with unknown node types, making up 0.81 of the nodes.</p><h3 style="margin: 1em 0 0 0;">Topological Oddities</h3><p class="paragraph">A topological oddity is a set of nodes in the graph that <i>may be derived</i> by an error during the generation of the edge list of the graph and, depending on the task, could bias the results of topology-based models. In the following paragraph, we will describe the detected topological oddities.</p><h4 style="margin: 1em 0 0 0;">Singleton nodes</h4><p class="paragraph">A singleton node is a node disconnected from all other nodes. We have detected 181 singleton nodes in the graph, involving a total of 181 nodes (0.93%). The detected singleton nodes are:</p><ul class="small-columns"><li><p class="paragraph">9606.ENSP00000278779 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000313324 (node types GO:0016020, GO:0016021, GO:0031224, GO:0110165, IPR031696 and other 6)</p></li>
# <li><p class="paragraph">9606.ENSP00000315794 (node type KW-0621)</p></li>
# <li><p class="paragraph">9606.ENSP00000316644 (node type KW-0025)</p></li>
# <li><p class="paragraph">9606.ENSP00000323241 (node type KW-0621)</p></li>
# <li><p class="paragraph">9606.ENSP00000335616 (node types BTO:0000000, BTO:0000042, BTO:0000142, BTO:0000211, BTO:0000227 and other 16)</p></li>
# <li><p class="paragraph">9606.ENSP00000362001 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000365108 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000365173 (node type KW-0025)</p></li>
# <li><p class="paragraph">9606.ENSP00000366765 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000367360 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000367449 (node types GO:0016020, GO:0016021, GO:0031224, GO:0110165, KW-0472 and other 3)</p></li>
# <li><p class="paragraph">9606.ENSP00000367983 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000368055 (unknown node type)</p></li>
# <li><p class="paragraph">9606.ENSP00000368292 (node types GO:0016020, GO:0016021, GO:0031224, GO:0110165, KW-0472 and other 2)</p></li></ul><p class="paragraph">And other 166 singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 16 isomorphic node groups in the graph, involving a total of 35 nodes (0.18%) and 4.46K edges (0.04%), with the largest one involving 3 nodes and 1.88K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 2 nodes (degree 941 and node types CL:3465, CL:3467, CL:3468, CL:3470, GO:0000413 and other 43): 9606.ENSP00000464619 and 9606.ENSP00000485638.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 397 and node type CL:4123): 9606.ENSP00000449334 and 9606.ENSP00000449223.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 216 and node types CL:37858, CL:37859, CL:37955, CL:37957, KW-0472 and other 3): 9606.ENSP00000439534 and 9606.ENSP00000456868.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 93 and node types CL:36688, CL:36774, CL:36775, CL:36776, CL:36803 and other 16): 9606.ENSP00000455596, 9606.ENSP00000339405 and 9606.ENSP00000485635.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 92 and node types CL:36688, CL:36774, CL:36775, CL:36776, GO:0005622 and other 15): 9606.ENSP00000485467 and 9606.ENSP00000455132.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 57 and node types CL:34541, CL:34542, CL:34650, GO:0000137, GO:0000139 and other 30): 9606.ENSP00000456894, 9606.ENSP00000457904 and 9606.ENSP00000323217.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 65 and node types CL:30792, CL:30793, CL:30794, CL:30936 and PF15623): 9606.ENSP00000392283 and 9606.ENSP00000393315.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 56 and node types CL:34541, CL:34542, CL:34650, CL:34696, GO:0000137 and other 29): 9606.ENSP00000391085 and 9606.ENSP00000300576.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 30 and node types GO:0003676, GO:0003677, GO:0005488, GO:0005622, GO:0005634 and other 45): 9606.ENSP00000382987, 9606.ENSP00000477043 and 9606.ENSP00000472160.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 41 and node types CL:31264, KW-0025 and KW-0621): 9606.ENSP00000330267 and 9606.ENSP00000485194.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 37 and node types CL:21787, CL:21953, GO:0016020, GO:0016021, GO:0031224 and another one): 9606.ENSP00000485610 and 9606.ENSP00000413537.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 35 and node types CL:37591, CL:37592, CL:37748, CL:37749, CL:37750 and other 3): 9606.ENSP00000469705 and 9606.ENSP00000484537.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 27 and node types CL:31664, CL:31665, CL:31700, CL:31716 and PF15483): 9606.ENSP00000482270 and 9606.ENSP00000480355.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 26 and node types GO:0005622, GO:0005737, GO:0005794, GO:0012505, GO:0043226 and other 8): 9606.ENSP00000421586 and 9606.ENSP00000479373.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 22 and node types BTO:0000000, BTO:0000042, BTO:0000123, BTO:0001244, BTO:0001418 and other 33): 9606.ENSP00000433597 and 9606.ENSP00000389275.</p></li></ol><p class="paragraph">And another isomorphic node group.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 16 tendrils in the graph, involving a total of 16 nodes (0.08%) and 32 edges. The detected tendrils are:</p><ul class="large-columns"><li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000006777 (degree 290), and containing a single other node, 9606.ENSP00000363495. Its nodes have 21 node types, of which the 10 most common are GO:0043231, GO:0110165, BTO:0000254, BTO:0000081, KW-0809, BTO:0003099, GO:0005737, BTO:0000083, GO:0043227 and BTO:0000042.</p></li>
# <li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000259631 (degree 438), and containing a single other node, 9606.ENSP00000457701.</p></li>
# <li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000261692 (degree 371), and containing a single other node, 9606.ENSP00000363242. Its nodes have 31 node types, of which the 10 most common are KW-0621, GO:0016604, GO:0031974, GO:0003677, GO:0005634, GO:0005654, GO:0043233, GO:1901363, KW-0238 and BTO:0000123.</p></li>
# <li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000298815 (degree 447), and containing a single other node, 9606.ENSP00000303999. Its nodes have 4 node types, which are CL:29064, KW-0812, KW-1133 and KW-0472.</p></li>
# <li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000316130 (degree 171), and containing a single other node, 9606.ENSP00000332389. Its nodes have 15 node types, of which the 10 most common are GO:0005615, GO:0031224, GO:0005576, KW-0472, PF04089, KW-0812, KW-1133, GO:0050794, GO:0110165 and GO:0050789.</p></li>
# <li><p class="paragraph">Tendril starting from the root node 9606.ENSP00000328287 (degree 1.50K), and containing a single other node, 9606.ENSP00000476986. Its nodes have a single node type, which is KW-0025.</p></li></ul><p class="paragraph">And other 10 tendrils.</p></div>

# %% [markdown]
# As suggested by the STRING authors, we filter the graph at `700`:

# %%
homo_sapiens = homo_sapiens.filter_from_names(min_edge_weight=700)

# %% [markdown]
# ### KGCOVID19
# [KGCOVID19](https://doi.org/10.1016%2Fj.patter.2020.100155) is a framework for producing knowledge graphs (KGs) that integrate and integrate biomedical data related to the COVID-19 pandemic. The framework is designed to be flexible and customizable, allowing researchers to create KGs for different downstream applications, including machine learning tasks, hypothesis-based querying, and browsable user interfaces for exploring and discovering relationships in COVID-19 data. The goal of KGCOVID19 is to provide an up-to-date, integrated source of data on SARS-CoV-2 and related viruses, including SARS-CoV and MERS-CoV, to support the biomedical research community in its efforts to respond to the COVID-19 pandemic. The framework can also be applied to other situations where siloed biomedical data must be quickly integrated for various research purposes, including future pandemics.

# %% [markdown]
# *⚠️ Heads up! This line of code will download a graph! Make sure you have a good internet connection and enough disk space before proceeding! 💾*

# %%
# %%time
from grape.datasets.kghub import KGCOVID19

kgcovid19 = KGCOVID19()
# Out:
# CPU times: user 23.3 s, sys: 222 ms, total: 23.5 s
# Wall time: 1.85 s

# %% [markdown]
# Let's take a look at its graph report:

# %%
kgcovid19
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>KGCOVID19</h2><p class="paragraph">The undirected multigraph KGCOVID19 has 574.23K heterogeneous nodes and 18.25M heterogeneous edges. The graph contains 30.98K connected components (of which 30.18K are disconnected nodes), with the largest one containing 540.07K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 80.99MB and 150.60MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 122.24K, the mode degree is 1, the mean degree is 63.57 and the node degree median is 4.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='https://ncbi.nlm.nih.gov/mesh/?term=D014780' target='_blank' title='Go to NCBI Mesh to get more informations about MESH:D014780'>MESH:D014780</a> (degree 122.24K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>), <a href='https://ncbi.nlm.nih.gov/mesh/?term=D006801' target='_blank' title='Go to NCBI Mesh to get more informations about MESH:D006801'>MESH:D006801</a> (degree 104.31K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>), <a href='https://ncbi.nlm.nih.gov/mesh/?term=D018352' target='_blank' title='Go to NCBI Mesh to get more informations about MESH:D018352'>MESH:D018352</a> (degree 92.93K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2697049' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2697049'>NCBITaxon:2697049</a> (degree 92.31K and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>, <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a> and <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>) and <a href='https://www.wikidata.org/wiki/Q30' target='_blank' title='Go to WikiData to get more informations about WD:Q30'>WD:Q30</a> (degree 92.14K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p><h3 style="margin: 1em 0 ...
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0O1KD' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0O1KD'>ttd.drug:D0O1KD</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D06FHW' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D06FHW'>ttd.drug:D06FHW</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D09RZX' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D09RZX'>ttd.drug:D09RZX</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0G2MM' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0G2MM'>ttd.drug:D0G2MM</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0S2TZ' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0S2TZ'>ttd.drug:D0S2TZ</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D06HIW' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D06HIW'>ttd.drug:D06HIW</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0E9IM' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0E9IM'>ttd.drug:D0E9IM</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D05BIJ' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D05BIJ'>ttd.drug:D05BIJ</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D04SDN' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D04SDN'>ttd.drug:D04SDN</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0M1VC' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0M1VC'>ttd.drug:D0M1VC</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0A1CB' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0A1CB'>ttd.drug:D0A1CB</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0H3TD' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0H3TD'>ttd.drug:D0H3TD</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0JL2K' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0JL2K'>ttd.drug:D0JL2K</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li>
# <li><p class="paragraph"><a href='http://db.idrblab.net/ttd/search/ttd/target?search_api_fulltext=D0Q2PE' target='_blank' title='Go to Therapeutic Target Database to get more informations about ttd.drug:D0Q2PE'>ttd.drug:D0Q2PE</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a>)</p></li></ul><p class="paragraph">And other 30.12K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Singleton nodes with self-loops</h4><p class="paragraph">A singleton node with self-loops is a node disconnected from all other nodes except itself. We have detected 44 singleton nodes with self-loops in the graph, involving a total of 44 nodes and 51 edges. The detected singleton nodes with self-loops are:</p><ul class="small-columns"><li><p class="paragraph"><a href='https://www.uniprot.org/uniprot/P0C6U8-PRO_0000338263' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P0C6U8-PRO_0000338263'>UniProtKB:P0C6U8-PRO_0000338263</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.uniprot.org/uniprot/P0C6X1-PRO_0000037301' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P0C6X1-PRO_0000037301'>UniProtKB:P0C6X1-PRO_0000037301</a> (node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>)</p></li>
# <li><p class="paragraph"><a href='http://identifiers.org/pombase/SPAC19B12.10' target='_blank' title='Go to POMBASE to get more informations about POMBASE::SPAC19B12.10'>POMBASE::SPAC19B12.10</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://www.wormbase.org/db/gene/gene?name=WBGene00021477' target='_blank' title='Go to WormBase to get more informations about WB:WBGene00021477'>WB:WBGene00021477</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:MGI:MGI:102463 (degree 4 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1604613 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:MGI:MGI:97548 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='http://zfin.org/ZDB-GENE-020812-1' target='_blank' title='Go to ZFIN to get more informations about ZFIN:ZDB-GENE-020812-1'>ZFIN:ZDB-GENE-020812-1</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-ALL-72617 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-141050 (degree 2 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-194019 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-72500 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:MGI:MGI:1933206 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-904821 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.uniprot.org/uniprot/P78423' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:P78423'>UniProtKB:P78423</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li></ul><p class="paragraph">And other 29 singleton nodes with self-loops.</p><h4 style="margin: 1em 0 0 0;">Chains</h4><p class="paragraph">A chain is a path of nodes with unique degree 2, that is ignoring self-loop and multi-edges, connecting two strongly connected components of the graph. We have detected 4 chains in the graph, involving a total of 41 nodes and 40 edges, with the largest one involving 11 nodes and 10 edges. The detected chains, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Chain containing 11 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=85604' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:85604'>NCBITaxon:85604</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>). Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7088' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7088'>NCBITaxon:7088</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=41191' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:41191'>NCBITaxon:41191</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=41196' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:41196'>NCBITaxon:41196</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=41197' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:41197'>NCBITaxon:41197</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=37567' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:37567'>NCBITaxon:37567</a> (node type <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>) and other 5. Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a> (10 nodes) and <a href='https://biolink.github.io/biolink-model/docs/Disease.html' target='_blank' title='Go to BioLink to get more informations about biolink:Disease'>biolink:Disease</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (20 edges, 9 ...
# <li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=133551' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:133551'>NCBITaxon:133551</a> (degree 3). Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7624' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7624'>NCBITaxon:7624</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7625' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7625'>NCBITaxon:7625</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7638' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7638'>NCBITaxon:7638</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7674' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7674'>NCBITaxon:7674</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2785018' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2785018'>NCBITaxon:2785018</a> (degree 3) and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 65.52%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (10 edges, 34.48%).</p></li>
# <li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=123369' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:123369'>NCBITaxon:123369</a> (degree 3). Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1489872' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1489872'>NCBITaxon:1489872</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1489908' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1489908'>NCBITaxon:1489908</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1489913' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1489913'>NCBITaxon:1489913</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=76071' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:76071'>NCBITaxon:76071</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=28781' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:28781'>NCBITaxon:28781</a> (degree 3) and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 65.52%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (10 edges, 34.48%).</p></li>
# <li><p class="paragraph">Chain containing 10 nodes and starts from the node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=70999' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:70999'>NCBITaxon:70999</a>. Specifically, the nodes involved in the chain are: <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=27479' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:27479'>NCBITaxon:27479</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33356' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33356'>NCBITaxon:33356</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33354' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33354'>NCBITaxon:33354</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33351' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33351'>NCBITaxon:33351</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33349' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33349'>NCBITaxon:33349</a> and other 4. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 95.00%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 355 node tuples in the graph, involving a total of 710 nodes (0.12%) and 355 edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-8941896 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-8942611 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5357900 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5357756 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-6785088 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-6785090 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-8953316 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-6784240 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-162387 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-162419 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://www.wormbase.org/db/gene/gene?name=CE52350' target='_blank' title='Go to WormBase to get more informations about WB:CE52350'>WB:CE52350</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://www.wormbase.org/db/gene/gene?name=WBGene00004010' target='_blank' title='Go to WormBase to get more informations about WB:WBGene00004010'>WB:WBGene00004010</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-71721 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-449914 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-532532 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-532536 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://identifiers.org/dictybase.gene/DDB_G0269152' target='_blank' title='Go to dictyBase Gene to get more informations about DICTYBASE.GENE:DDB_G0269152'>DICTYBASE.GENE:DDB_G0269152</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://identifiers.org/dictybase.gene/DDB_G0286353' target='_blank' title='Go to dictyBase Gene to get more informations about DICTYBASE.GENE:DDB_G0286353'>DICTYBASE.GENE:DDB_G0286353</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-72075 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-71997 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-51645 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-9632658 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5173031 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5173226 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-448628 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-9009553 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1799327 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1799337 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-548936 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-391115 (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><p class="paragraph">And other 340 node tuples.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 17.73K isomorphic node groups in the graph, involving a total of 39.58K nodes (6.89%) and 1.41M edges (3.87%), with the largest one involving 575 nodes and 28.75K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 575 nodes (degree 50 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A6H1PJ53' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H1PJ53'>UniProtKB:A0A6H1PJ53</a>, <a href='https://www.uniprot.org/uniprot/A0A6H1XQ14' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H1XQ14'>UniProtKB:A0A6H1XQ14</a>, <a href='https://www.uniprot.org/uniprot/A0A6G9KCX0' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6G9KCX0'>UniProtKB:A0A6G9KCX0</a>, <a href='https://www.uniprot.org/uniprot/A0A6G9KCX9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6G9KCX9'>UniProtKB:A0A6G9KCX9</a>, <a href='https://www.uniprot.org/uniprot/A0A6H1PL31' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H1PL31'>UniProtKB:A0A6H1PL31</a> and other 570.</p></li>
# <li><p class="paragraph">Group with 69 nodes (degree 388 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:0bc493404a0f56928b1f5762c40cd1952e563e7d, CORD:47f1e83a120bb84f7cbb95319be9fb47a4c885fd, CORD:488417f8f7e0fa031c597925b4801d7755080e49, CORD:9ac60deb0aa49d96f78275c325d24294da9f6f94, CORD:ea3b1c4721836f94e19de86c26c6dbeb00153b5c and other 64.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 9.41K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>): <a href='http://purl.uniprot.org/uniprot/P59595' target='_blank' title='Go to Translation of EMBL nucleotide sequence database to get more informations about TrEMBL:P59595'>TrEMBL:P59595</a> and <a href='http://purl.obolibrary.org/obo/PR_P0DTC9' target='_blank' title='Go to PRotein Ontology (PRO) to get more informations about PR:P0DTC9'>PR:P0DTC9</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 4.71K and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>): <a href='http://amigo.geneontology.org/amigo/term/GO:0050397' target='_blank' title='Go to Gene Ontology to get more informations about GO:0050397'>GO:0050397</a>, <a href='http://amigo.geneontology.org/amigo/term/GO:0047712' target='_blank' title='Go to Gene Ontology to get more informations about GO:0047712'>GO:0047712</a> and <a href='http://amigo.geneontology.org/amigo/term/GO:0050248' target='_blank' title='Go to Gene Ontology to get more informations about GO:0050248'>GO:0050248</a>.</p></li>
# <li><p class="paragraph">Group with 339 nodes (degree 28 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A6H1PJ74' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H1PJ74'>UniProtKB:A0A6H1PJ74</a>, <a href='https://www.uniprot.org/uniprot/A0A6H2LCI4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H2LCI4'>UniProtKB:A0A6H2LCI4</a>, <a href='https://www.uniprot.org/uniprot/A0A6H2EEY3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H2EEY3'>UniProtKB:A0A6H2EEY3</a>, <a href='https://www.uniprot.org/uniprot/A0A6H1PIH5' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H1PIH5'>UniProtKB:A0A6H1PIH5</a>, <a href='https://www.uniprot.org/uniprot/A0A6H0C630' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H0C630'>UniProtKB:A0A6H0C630</a> and other 334.</p></li>
# <li><p class="paragraph">Group with 14 nodes (degree 530 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:40e2c8802073af98c814a8cad3a035961da7ccb5, CORD:1aa3d8e4824c9ea70928487e62c7b1e16111d425, CORD:e1e16f7e22d04879de8412d4cb0f05d4419d8fc2, CORD:79e6929cbb7b35a18475c1e077bf7406aac962e8, CORD:8508fe38cac94bf59df0d7e9aebdb803ea8f65a6 and other 9.</p></li>
# <li><p class="paragraph">Group with 16 nodes (degree 433 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:306bbc07c2046e6931c629582fc8f63ba4ba3ac6, CORD:64d8f7c693bf4a66b4a4fa41c3dbb2d1021874ea, CORD:f86441be43fa2f6c86d86530c46ee2dbef016f99, CORD:fc11dc20545fe3c977474443ae533a44d851e24c, CORD:31f564466fdeeb0516c61d869642275ea48d798b and other 11.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 2.37K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>): <a href='http://amigo.geneontology.org/amigo/term/GO:0051805' target='_blank' title='Go to Gene Ontology to get more informations about GO:0051805'>GO:0051805</a> and <a href='http://amigo.geneontology.org/amigo/term/GO:0051842' target='_blank' title='Go to Gene Ontology to get more informations about GO:0051842'>GO:0051842</a>.</p></li>
# <li><p class="paragraph">Group with 5 nodes (degree 862 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:19cceaebefd2e6db1428997fa917452617d8e9a0, CORD:4cdb6a1242ea80f27e5f9cad36826f794bb7e80d, CORD:df8ad25b3979056ceca8815c91d79efdec5f4f9e, CORD:94397d7d7dbb362b167ba30c155c1cd02cd94d77 and CORD:becef58fd196717784624efec41d78758b13c959.</p></li>
# <li><p class="paragraph">Group with 185 nodes (degree 16 and node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>): <a href='https://www.uniprot.org/uniprot/A0A6H2EGA9' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H2EGA9'>UniProtKB:A0A6H2EGA9</a>, <a href='https://www.uniprot.org/uniprot/A0A6G9ZX63' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6G9ZX63'>UniProtKB:A0A6G9ZX63</a>, <a href='https://www.uniprot.org/uniprot/A0A6G7K2M4' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6G7K2M4'>UniProtKB:A0A6G7K2M4</a>, <a href='https://www.uniprot.org/uniprot/A0A6G9ZWV6' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6G9ZWV6'>UniProtKB:A0A6G9ZWV6</a>, <a href='https://www.uniprot.org/uniprot/A0A6H2LAK3' target='_blank' title='Go to UniProtKB to get more informations about UniProtKB:A0A6H2LAK3'>UniProtKB:A0A6H2LAK3</a> and other 180.</p></li>
# <li><p class="paragraph">Group with 9 nodes (degree 259 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:e6cf8eac44bbbe1ca4404aba91d2508542c4374e, CORD:71b9ba9d8b0cfcdc81aa2a4223daac0405e27ee4, CORD:ab960d016b2a616db7ba8e6e93b6b26ac3dd8e28, CORD:6a26e016f24c28c30569287c8db0b30ed2c4ebe8, CORD:c08d9247906f6775d2fc84702d013c7fd06822f3 and other 4.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 1.07K and node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>): <a href='http://identifiers.org/chembl.compound/CHEMBL388581' target='_blank' title='Go to Chembl Compound to get more informations about CHEMBL.COMPOUND:CHEMBL388581'>CHEMBL.COMPOUND:CHEMBL388581</a> and <a href='http://identifiers.org/chembl.compound/CHEMBL132268' target='_blank' title='Go to Chembl Compound to get more informations about CHEMBL.COMPOUND:CHEMBL132268'>CHEMBL.COMPOUND:CHEMBL132268</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 844 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:eb263e0a8cbb58a5f9569993efc4b18edfe7a657 and CORD:afb0df1b73955b25beb239ce63e716f93c46b847.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 834 and node type <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a>): CORD:3c1f47a07aaf0e393dee9fbd08596a4b9f4f0a03 and CORD:c28a97c16c1665bbc45dcbab1b48fdcd78db83c2.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 794 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/CellularComponent.html' target='_blank' title='Go to BioLink to get more informations about biolink:CellularComponent'>biolink:CellularComponent</a>): <a href='http://amigo.geneontology.org/amigo/term/GO:0019038' target='_blank' title='Go to Gene Ontology to get more informations about GO:0019038'>GO:0019038</a> and <a href='https://ncbi.nlm.nih.gov/mesh/?term=D011533' target='_blank' title='Go to NCBI Mesh to get more informations about MESH:D011533'>MESH:D011533</a>.</p></li></ol><p class="paragraph">And other 17.71K isomorphic node groups.</p><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected 71 trees in the graph, involving a total of 516 nodes (0.09%) and 890 edges, with the largest one involving 17 nodes and 32 edges. The detected trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tree starting from the root node :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-179864 (degree 8), and containing 17 nodes, with a maximal depth of 2, which are :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5654194, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5654191, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5654186, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5654185 and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5654203. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/positively_regulates.html' target='_blank' title='Go to BioLink to get more informations about biolink:positively_regulates'>biolink:positively_regulates</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-176479 (degree 2), and containing 15 nodes, with a maximal depth of 2, which are :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-176573 (degree 13), :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-5695994, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-176599, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-176569 and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-158473. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/precedes.html' target='_blank' title='Go to BioLink to get more informations about biolink:precedes'>biolink:precedes</a> (25 edges, 96.15%) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li>
# ...
# <li><p class="paragraph">Free-floating chain starting from the root node :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-198701 (degree 3), and containing 5 nodes, with a maximal depth of 2, which are :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-199849, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-3009350, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-198683 and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-199878. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/positively_regulates.html' target='_blank' title='Go to BioLink to get more informations about biolink:positively_regulates'>biolink:positively_regulates</a> (4 edges) and <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-196775 (degree 3), and containing 5 nodes, with a maximal depth of 2, which are :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-196828, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-199195, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-196803 and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-196735. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/related_to.html' target='_blank' title='Go to BioLink to get more informations about biolink:related_to'>biolink:related_to</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1252240 (degree 3), and containing 5 nodes, with a maximal depth of 2, which are :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1252098, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1252247, :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1252140 and :OBO:go&#x2f;extensions&#x2f;reacto.owl#REACTO_R-HSA-1955377. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/precedes.html' target='_blank' title='Go to BioLink to get more informations about biolink:precedes'>biolink:precedes</a>.</p></li></ol><p class="paragraph">And other 46 free-floating chains.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 24.45K tendrils in the graph, involving a total of 24.90K nodes (4.34%) and 49.81K edges (0.14%), with the largest one involving 10 nodes and 20 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=32561' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:32561'>NCBITaxon:32561</a> (degree 4), and containing 10 nodes, with a maximal depth of 10, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8504' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8504'>NCBITaxon:8504</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8509' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8509'>NCBITaxon:8509</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1329961' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1329961'>NCBITaxon:1329961</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1329950' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1329950'>NCBITaxon:1329950</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1329912' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1329912'>NCBITaxon:1329912</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 65.52%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (10 edges, 34.48%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7586' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7586'>NCBITaxon:7586</a> (degree 4), and containing 10 nodes, with a maximal depth of 10, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=133551' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:133551'>NCBITaxon:133551</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7624' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7624'>NCBITaxon:7624</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7625' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7625'>NCBITaxon:7625</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7638' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7638'>NCBITaxon:7638</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7674' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7674'>NCBITaxon:7674</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (19 edges, 65.52%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (10 edges, 34.48%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43741' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43741'>NCBITaxon:43741</a> (degree 4), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43746' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43746'>NCBITaxon:43746</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7214' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7214'>NCBITaxon:7214</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=43845' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:43845'>NCBITaxon:43845</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=46877' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:46877'>NCBITaxon:46877</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=7215' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:7215'>NCBITaxon:7215</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (17 edges, 65.38%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (9 edges, 34.62%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=32523' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:32523'>NCBITaxon:32523</a> (degree 20), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8292' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8292'>NCBITaxon:8292</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=41666' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:41666'>NCBITaxon:41666</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8342' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8342'>NCBITaxon:8342</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=30319' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:30319'>NCBITaxon:30319</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8352' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8352'>NCBITaxon:8352</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (17 edges, 65.38%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (9 edges, 34.62%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1206795' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1206795'>NCBITaxon:1206795</a> (degree 6), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6447' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6447'>NCBITaxon:6447</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6448' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6448'>NCBITaxon:6448</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=216275' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:216275'>NCBITaxon:216275</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2315720' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2315720'>NCBITaxon:2315720</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=216285' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:216285'>NCBITaxon:216285</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=112252' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:112252'>NCBITaxon:112252</a> (degree 6), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4761' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4761'>NCBITaxon:4761</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2683659' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2683659'>NCBITaxon:2683659</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=451435' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:451435'>NCBITaxon:451435</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=451442' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:451442'>NCBITaxon:451442</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1142503' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1142503'>NCBITaxon:1142503</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (15 edges, 65.22%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (8 edges, 34.78%).</p></li></ol><p class="paragraph">And other 24.44K tendrils.</p></div>

# %% [markdown]
# ### PubMed
# PubMed is a database of biomedical literature maintained by the National Institutes of Health (NIH). It includes citations and abstracts for articles from a wide range of biomedical journals, as well as links to full-text articles when available. PubMed is a valuable resource for researchers and clinicians who are looking for information on biomedical topics.
#
# [The following is a PubMed citation graph that I personally created](https://github.com/LucaCappelletti94/pubmed_embedding). This graph represents the relationships between articles in the PubMed database. The nodes of the graph represent articles, and the edges represent the citations between the articles.

# %% [markdown]
# *⚠️ Heads up! This line of code will download a graph! Make sure you have a good internet connection and enough disk space before proceeding! 💾*

# %%
# %%time
from grape.datasets.pubmed import PubMed

pubmed = PubMed()
# Out:
# CPU times: user 5min 21s, sys: 6.19 s, total: 5min 27s
# Wall time: 31.7 s

# %% [markdown]
# Since all other graphs we are considering have edge types, let's add a proper one also to PubMed:

# %%
pubmed.set_inplace_all_edge_types("biolink:Mentions")

# %% [markdown]
# This graph is built from the XML data provided by PubMed, but this means it contains many singleton nodes, i.e. articles for which we do not know the citations. We can drop them.

# %%
pubmed = pubmed.remove_singleton_nodes()

# %% [markdown]
# Let's take a look at its graph report:

# %%
pubmed
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>PubMed</h2><p class="paragraph">The undirected graph PubMed has 21.59M nodes and 249.17M homogeneous edges. The graph contains 16.75K connected components (of which 725 are disconnected nodes), with the largest one containing 21.55M nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 2.26GB and 2.17GB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 1, the maximum node degree is 54.93K, the mode degree is 1, the mean degree is 23.08 and the node degree median is 8.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='https://pubmed.ncbi.nlm.nih.gov/5432063/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5432063'>PMID:5432063</a> (degree 54.93K), <a href='https://pubmed.ncbi.nlm.nih.gov/11846609/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11846609'>PMID:11846609</a> (degree 54.17K), <a href='https://pubmed.ncbi.nlm.nih.gov/14907713/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14907713'>PMID:14907713</a> (degree 53.59K), <a href='https://pubmed.ncbi.nlm.nih.gov/942051/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:942051'>PMID:942051</a> (degree 46.13K) and <a href='https://pubmed.ncbi.nlm.nih.gov/2231712/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2231712'>PMID:2231712</a> (degree 28.32K).</p><h3 style="margin: 1em 0 0 0;">Edge types</h3><p class="paragraph">The graph has a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>. The RAM requirement for the edge types data structure is 1.99GB.</p><h3 style="margin: 1em 0 0 0;">Topological Oddities</h3><p class="paragraph">A topological oddity is a set of nodes in the graph that <i>may be derived</i> by an error during the generation of the edge list of the graph and, depending on the task, could bias the results of topology-based models. In the following paragraph, we will describe the detected topological oddities.</p><h4 style="margin: 1em 0 0 0;">Singleton nodes with self-loops</h4><p class="paragraph">A singleton node with self-loops is a node disconnected from all other nodes except itself. We have detected 725 singleton nodes with self-loops in the graph, involving a total of 725 nodes and 725 edges. The detected singleton nodes with self-loops are:</p><ul class="small-columns"><li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/529238/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:529238'>PMID:529238</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/536970/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:536970'>PMID:536970</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/541793/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:541793'>PMID:541793</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/541794/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:541794'>PMID:541794</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/541800/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:541800'>PMID:541800</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/544804/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:544804'>PMID:544804</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/702446/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:702446'>PMID:702446</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/1286377/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1286377'>PMID:1286377</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/1286390/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1286390'>PMID:1286390</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/1998797/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1998797'>PMID:1998797</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/2496869/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2496869'>PMID:2496869</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/2497834/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2497834'>PMID:2497834</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/2502227/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2502227'>PMID:2502227</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/2514927/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2514927'>PMID:2514927</a></p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/2514928/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2514928'>PMID:2514928</a></p></li></ul><p class="paragraph">And other 710 singleton nodes with self-loops.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 11.79K node tuples in the graph, involving a total of 23.58K nodes (0.11%) and 11.79K edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34877640/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34877640'>PMID:34877640</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34893962/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34893962'>PMID:34893962</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34857911/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34857911'>PMID:34857911</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34876676/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34876676'>PMID:34876676</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34856121/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34856121'>PMID:34856121</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34887586/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34887586'>PMID:34887586</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34853424/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34853424'>PMID:34853424</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34853458/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34853458'>PMID:34853458</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34852237/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34852237'>PMID:34852237</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34862485/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34862485'>PMID:34862485</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34839428/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34839428'>PMID:34839428</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34853945/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34853945'>PMID:34853945</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34824478/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34824478'>PMID:34824478</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34857935/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34857935'>PMID:34857935</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34822779/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34822779'>PMID:34822779</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34857918/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34857918'>PMID:34857918</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34822775/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34822775'>PMID:34822775</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34880394/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34880394'>PMID:34880394</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34814483/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34814483'>PMID:34814483</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34888120/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34888120'>PMID:34888120</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34812986/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34812986'>PMID:34812986</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34853941/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34853941'>PMID:34853941</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34807518/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34807518'>PMID:34807518</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34862491/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34862491'>PMID:34862491</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34806164/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34806164'>PMID:34806164</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34887547/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34887547'>PMID:34887547</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34801749/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34801749'>PMID:34801749</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34845385/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34845385'>PMID:34845385</a>.</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/34799405/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34799405'>PMID:34799405</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34880470/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34880470'>PMID:34880470</a>.</p></li></ul><p class="paragraph">And other 11.78K node tuples.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 2.01K isomorphic node groups in the graph, involving a total of 4.70K nodes (0.02%) and 48.33K edges, with the largest one involving 146 nodes and 2.24K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 10 nodes (degree 224): <a href='https://pubmed.ncbi.nlm.nih.gov/28766777/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766777'>PMID:28766777</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766776/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766776'>PMID:28766776</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766774/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766774'>PMID:28766774</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766783/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766783'>PMID:28766783</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766772/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766772'>PMID:28766772</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 96 nodes (degree 8): <a href='https://pubmed.ncbi.nlm.nih.gov/34486065/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34486065'>PMID:34486065</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34546875/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34546875'>PMID:34546875</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34486066/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34486066'>PMID:34486066</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34483134/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34483134'>PMID:34483134</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34483115/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34483115'>PMID:34483115</a> and other 91.</p></li>
# <li><p class="paragraph">Group with 146 nodes (degree 5): <a href='https://pubmed.ncbi.nlm.nih.gov/10730073/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10730073'>PMID:10730073</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9178313/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9178313'>PMID:9178313</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/2424639/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2424639'>PMID:2424639</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9476319/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9476319'>PMID:9476319</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9203211/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9203211'>PMID:9203211</a> and other 141.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 365): <a href='https://pubmed.ncbi.nlm.nih.gov/34589512/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34589512'>PMID:34589512</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34790692/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34790692'>PMID:34790692</a>.</p></li>
# <li><p class="paragraph">Group with 32 nodes (degree 14): <a href='https://pubmed.ncbi.nlm.nih.gov/29637355/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637355'>PMID:29637355</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637326/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637326'>PMID:29637326</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637343/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637343'>PMID:29637343</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637347/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637347'>PMID:29637347</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637363/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637363'>PMID:29637363</a> and other 27.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 222): <a href='https://pubmed.ncbi.nlm.nih.gov/34359080/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34359080'>PMID:34359080</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34362780/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34362780'>PMID:34362780</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 180): <a href='https://pubmed.ncbi.nlm.nih.gov/30255389/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30255389'>PMID:30255389</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/30255464/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30255464'>PMID:30255464</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 86): <a href='https://pubmed.ncbi.nlm.nih.gov/34282481/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34282481'>PMID:34282481</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34076782/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34076782'>PMID:34076782</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34037807/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34037807'>PMID:34037807</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 109): <a href='https://pubmed.ncbi.nlm.nih.gov/29552348/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29552348'>PMID:29552348</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/29861556/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29861556'>PMID:29861556</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 108): <a href='https://pubmed.ncbi.nlm.nih.gov/32288974/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32288974'>PMID:32288974</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/18781266/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18781266'>PMID:18781266</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 91): <a href='https://pubmed.ncbi.nlm.nih.gov/28879382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28879382'>PMID:28879382</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/21505933/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21505933'>PMID:21505933</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 89): <a href='https://pubmed.ncbi.nlm.nih.gov/26716047/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26716047'>PMID:26716047</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/26697462/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26697462'>PMID:26697462</a>.</p></li>
# <li><p class="paragraph">Group with 4 nodes (degree 43): <a href='https://pubmed.ncbi.nlm.nih.gov/31019926/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:31019926'>PMID:31019926</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/30983746/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30983746'>PMID:30983746</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/30758679/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30758679'>PMID:30758679</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/32734178/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32734178'>PMID:32734178</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 86): <a href='https://pubmed.ncbi.nlm.nih.gov/34305047/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34305047'>PMID:34305047</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34311518/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34311518'>PMID:34311518</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 84): <a href='https://pubmed.ncbi.nlm.nih.gov/32336937/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32336937'>PMID:32336937</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/32336936/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32336936'>PMID:32336936</a>.</p></li></ol><p class="paragraph">And other 2.00K isomorphic node groups.</p><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected 165 trees in the graph, involving a total of 1.07K nodes and 1.81K edges, with the largest one involving 18 nodes and 34 edges. The detected trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/32874261/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874261'>PMID:32874261</a> (degree 2), and containing 18 nodes, with a maximal depth of 4, which are <a href='https://pubmed.ncbi.nlm.nih.gov/32695237/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32695237'>PMID:32695237</a> (degree 8), <a href='https://pubmed.ncbi.nlm.nih.gov/33082870/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33082870'>PMID:33082870</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32874258/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874258'>PMID:32874258</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32874262/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874262'>PMID:32874262</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/32874263/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874263'>PMID:32874263</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13296855/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13296855'>PMID:13296855</a> (degree 3), and containing 17 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/5302972/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5302972'>PMID:5302972</a> (degree 5), <a href='https://pubmed.ncbi.nlm.nih.gov/13837688/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13837688'>PMID:13837688</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/14336746/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14336746'>PMID:14336746</a> (degree 9), <a href='https://pubmed.ncbi.nlm.nih.gov/13079044/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13079044'>PMID:13079044</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/13458970/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13458970'>PMID:13458970</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/34136007/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34136007'>PMID:34136007</a> (degree 11), and containing 15 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/32695239/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32695239'>PMID:32695239</a> (degree 4), <a href='https://pubmed.ncbi.nlm.nih.gov/34400975/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34400975'>PMID:34400975</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34400976/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34400976'>PMID:34400976</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34400978/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34400978'>PMID:34400978</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34408798/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34408798'>PMID:34408798</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/1130567/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1130567'>PMID:1130567</a> (degree 3), and containing 14 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/5224236/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5224236'>PMID:5224236</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/5244498/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5244498'>PMID:5244498</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9617072/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9617072'>PMID:9617072</a> (degree 11), <a href='https://pubmed.ncbi.nlm.nih.gov/4509539/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:4509539'>PMID:4509539</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/5261552/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5261552'>PMID:5261552</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/11497556/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11497556'>PMID:11497556</a> (degree 2), and containing 12 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/15372309/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:15372309'>PMID:15372309</a> (degree 4), <a href='https://pubmed.ncbi.nlm.nih.gov/15685436/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:15685436'>PMID:15685436</a> (degree 7), <a href='https://pubmed.ncbi.nlm.nih.gov/12484840/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12484840'>PMID:12484840</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12935138/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12935138'>PMID:12935138</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/18183263/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18183263'>PMID:18183263</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13778233/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13778233'>PMID:13778233</a> (degree 4), and containing 12 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/5987935/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5987935'>PMID:5987935</a> (degree 8), <a href='https://pubmed.ncbi.nlm.nih.gov/13548769/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13548769'>PMID:13548769</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13613663/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13613663'>PMID:13613663</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13613664/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13613664'>PMID:13613664</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/13086234/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13086234'>PMID:13086234</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 159 trees.</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 5.10K dendritic trees in the graph, involving a total of 35.04K nodes (0.16%) and 70.08K edges (0.01%), with the largest one involving 2.92K nodes and 5.84K edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/18156677/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18156677'>PMID:18156677</a> (degree 28.17K), and containing 2.92K nodes, with a maximal depth of 3, which are <a href='https://pubmed.ncbi.nlm.nih.gov/20072813/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20072813'>PMID:20072813</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20203389/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20203389'>PMID:20203389</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20203392/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20203392'>PMID:20203392</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/21200980/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21200980'>PMID:21200980</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/21200982/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21200982'>PMID:21200982</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/7469924/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7469924'>PMID:7469924</a> (degree 623), and containing 243 nodes, with a maximal depth of 3, which are <a href='https://pubmed.ncbi.nlm.nih.gov/17949/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17949'>PMID:17949</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/128676/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:128676'>PMID:128676</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/135896/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:135896'>PMID:135896</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/175228/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:175228'>PMID:175228</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/334463/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:334463'>PMID:334463</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13219341/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13219341'>PMID:13219341</a> (degree 559), and containing 234 nodes, with a maximal depth of 4, which are <a href='https://pubmed.ncbi.nlm.nih.gov/12975866/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12975866'>PMID:12975866</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976390/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976390'>PMID:12976390</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976773/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976773'>PMID:12976773</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976907/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976907'>PMID:12976907</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/12978282/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12978282'>PMID:12978282</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/25972760/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:25972760'>PMID:25972760</a> (degree 405), and containing 180 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/9913687/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9913687'>PMID:9913687</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9959011/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9959011'>PMID:9959011</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9959454/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9959454'>PMID:9959454</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9968421/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9968421'>PMID:9968421</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/9970594/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9970594'>PMID:9970594</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13511135/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13511135'>PMID:13511135</a> (degree 406), and containing 172 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/12980793/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12980793'>PMID:12980793</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12982739/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12982739'>PMID:12982739</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12995471/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12995471'>PMID:12995471</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12995472/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12995472'>PMID:12995472</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/12995474/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12995474'>PMID:12995474</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/580740/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:580740'>PMID:580740</a> (degree 332), and containing 149 nodes, with a maximal depth of 3, which are <a href='https://pubmed.ncbi.nlm.nih.gov/123571/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:123571'>PMID:123571</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/129610/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:129610'>PMID:129610</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/129633/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:129633'>PMID:129633</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/134212/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:134212'>PMID:134212</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/134217/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:134217'>PMID:134217</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 5.09K dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected 3.51K stars in the graph, involving a total of 12.22K nodes (0.06%) and 17.43K edges, with the largest one involving 19 nodes and 36 edges. The detected stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Star starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13445095/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13445095'>PMID:13445095</a> (degree 18), and containing 19 nodes, with a maximal depth of 1, which are <a href='https://pubmed.ncbi.nlm.nih.gov/12989650/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12989650'>PMID:12989650</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13004409/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13004409'>PMID:13004409</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13038640/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13038640'>PMID:13038640</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13092153/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13092153'>PMID:13092153</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/13164500/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13164500'>PMID:13164500</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/326321/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:326321'>PMID:326321</a> (degree 14), and containing 15 nodes, with a maximal depth of 1, which are <a href='https://pubmed.ncbi.nlm.nih.gov/233980/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:233980'>PMID:233980</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/775986/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:775986'>PMID:775986</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/939513/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:939513'>PMID:939513</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/1044211/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1044211'>PMID:1044211</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/1046881/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1046881'>PMID:1046881</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/5613483/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5613483'>PMID:5613483</a> (degree 12), and containing 13 nodes, with a maximal depth of 1, which are <a href='https://pubmed.ncbi.nlm.nih.gov/13042379/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13042379'>PMID:13042379</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13125483/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13125483'>PMID:13125483</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13223003/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13223003'>PMID:13223003</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13423718/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13423718'>PMID:13423718</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/13564291/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13564291'>PMID:13564291</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/27805076/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:27805076'>PMID:27805076</a> (degree 12), and containing 13 nodes, with a maximal depth of 1, which are <a href='https://pubmed.ncbi.nlm.nih.gov/9896761/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9896761'>PMID:9896761</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9908420/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9908420'>PMID:9908420</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9908596/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9908596'>PMID:9908596</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9937946/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9937946'>PMID:9937946</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/9942295/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9942295'>PMID:9942295</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Star starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/20793278/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20793278'>PMID:20793278</a> (degree 10), and containing 11 nodes, with a maximal depth of 1, which are <a href='https://pubmed.ncbi.nlm.nih.gov/20794677/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20794677'>PMID:20794677</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20794684/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20794684'>PMID:20794684</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20794687/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20794687'>PMID:20794687</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20794689/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20794689'>PMID:20794689</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/20794691/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20794691'>PMID:20794691</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# ...
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/6860815/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:6860815'>PMID:6860815</a> (degree 4), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/239045/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:239045'>PMID:239045</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/2306526/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2306526'>PMID:2306526</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/5083528/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5083528'>PMID:5083528</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/7252058/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7252058'>PMID:7252058</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/1139053/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1139053'>PMID:1139053</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/14900365/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14900365'>PMID:14900365</a> (degree 4), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/18011690/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18011690'>PMID:18011690</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/18014211/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18014211'>PMID:18014211</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/18891216/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18891216'>PMID:18891216</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/18905853/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18905853'>PMID:18905853</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/13207483/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13207483'>PMID:13207483</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/8343732/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:8343732'>PMID:8343732</a> (degree 4), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/7661970/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7661970'>PMID:7661970</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/8401003/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:8401003'>PMID:8401003</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/8401004/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:8401004'>PMID:8401004</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/8401083/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:8401083'>PMID:8401083</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/492810/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:492810'>PMID:492810</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/20314367/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20314367'>PMID:20314367</a> (degree 3), and containing 5 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/11643682/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11643682'>PMID:11643682</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20313877/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20313877'>PMID:20313877</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20314477/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20314477'>PMID:20314477</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/20313704/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20313704'>PMID:20313704</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/19973326/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19973326'>PMID:19973326</a> (degree 3), and containing 5 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/19981288/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19981288'>PMID:19981288</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/19986847/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19986847'>PMID:19986847</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20769404/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20769404'>PMID:20769404</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/19973625/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19973625'>PMID:19973625</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 208 free-floating chains.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 1.25M tendrils in the graph, involving a total of 1.26M nodes (5.83%) and 2.52M edges (0.51%), with the largest one involving 6 nodes and 12 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/2316051/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2316051'>PMID:2316051</a> (degree 9), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://pubmed.ncbi.nlm.nih.gov/3122440/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:3122440'>PMID:3122440</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/3218382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:3218382'>PMID:3218382</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/7423666/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7423666'>PMID:7423666</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/7071997/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7071997'>PMID:7071997</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/835200/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:835200'>PMID:835200</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/4647484/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:4647484'>PMID:4647484</a> (degree 5), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://pubmed.ncbi.nlm.nih.gov/23119595/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23119595'>PMID:23119595</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/23120285/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23120285'>PMID:23120285</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/23119603/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23119603'>PMID:23119603</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/27407652/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:27407652'>PMID:27407652</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/23119730/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23119730'>PMID:23119730</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/27131647/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:27131647'>PMID:27131647</a> (degree 10), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://pubmed.ncbi.nlm.nih.gov/33053833/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33053833'>PMID:33053833</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34067247/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34067247'>PMID:34067247</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32033246/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32033246'>PMID:32033246</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28672830/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28672830'>PMID:28672830</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/26927117/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26927117'>PMID:26927117</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/11630508/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11630508'>PMID:11630508</a> (degree 34), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/926128/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:926128'>PMID:926128</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/430527/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:430527'>PMID:430527</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/966262/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:966262'>PMID:966262</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/633311/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:633311'>PMID:633311</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/1165578/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1165578'>PMID:1165578</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/31828438/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:31828438'>PMID:31828438</a> (degree 18), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/24091970/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24091970'>PMID:24091970</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/24058934/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24058934'>PMID:24058934</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/24091971/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24091971'>PMID:24091971</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/23765466/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23765466'>PMID:23765466</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/23823785/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:23823785'>PMID:23823785</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13219396/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13219396'>PMID:13219396</a> (degree 7), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/19990949/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19990949'>PMID:19990949</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/19993517/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19993517'>PMID:19993517</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/19992718/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19992718'>PMID:19992718</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/19993277/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19993277'>PMID:19993277</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/19992719/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:19992719'>PMID:19992719</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 1.25M tendrils.</p></div>

# %% [markdown]
# ### Merging ontologies
#
# In this section, we are merging the Human Phenotype Ontology (HPO) and the Mammalian Phenotype Ontology (MPO) using the union operator `or` (`|`). The union operator combines the elements of two sets into a single set, with no duplicate elements. In this case, the resulting set `hp_or_mp` will contain all of the elements from the HPO and the MPO, without any duplicates.
#
# The use of the union operator here is useful because it allows us to combine the two ontologies into a single set, making it easier to work with and analyze the data.

# %%
# %%time
hp_or_mp = hpo | mpo
# Out:
# CPU times: user 653 ms, sys: 1.84 s, total: 2.49 s
# Wall time: 128 ms

# %% [markdown]
# Let's check out the graph report:

# %%
hp_or_mp
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>(HP | MP)</h2><p class="paragraph">The undirected multigraph (HP | MP) has 57.01K heterogeneous nodes and 98.24K heterogeneous edges. The graph contains 2.59K connected components (of which 2.57K are disconnected nodes), with the largest one containing 36.82K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 5.95MB and 1.24MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 2.03K, the mode degree is 1, the mean degree is 3.45 and the node degree median is 2.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://amigo.geneontology.org/amigo/term/GO:0065007' target='_blank' title='Go to Gene Ontology to get more informations about GO:0065007'>GO:0065007</a> (degree 2.03K and node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a>), <a href='http://orcid.org/0000-0002-6490-7723' target='_blank' title='Go to website to get more informations about http:&#x2f;&#x2f;orcid.org&#x2f;0000-0002-6490-7723'>http:&#x2f;&#x2f;orcid.org&#x2f;0000-0002-6490-7723</a> (degree 1.28K and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/mp-edit#IMPC' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:mp-edit#IMPC'>OBO:mp-edit#IMPC</a> (degree 624 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/CARO_0000000' target='_blank' title='Go to Common Anatomy Reference Ontology to get more informations about CARO:0000000'>CARO:0000000</a> (degree 569 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://orcid.org/0000-0003-4606-0597' target='_blank' title='Go to website to get more informations about http:&#x2f;&#x2f;orcid.org&#x2f;0000-0003-4606-0597'>http:&#x2f;&#x2f;orcid.org&#x2f;0000-0003-4606-0597</a> (degree 558 and node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 12 node types, of which the 10 most common are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations abou ...
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:15373' target='_blank' title='Go to CHEBI to get more informations about CHEBI:15373'>CHEBI:15373</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:15377' target='_blank' title='Go to CHEBI to get more informations about CHEBI:15377'>CHEBI:15377</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:15422' target='_blank' title='Go to CHEBI to get more informations about CHEBI:15422'>CHEBI:15422</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16240' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16240'>CHEBI:16240</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16301' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16301'>CHEBI:16301</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16330' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16330'>CHEBI:16330</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16393' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16393'>CHEBI:16393</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16761' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16761'>CHEBI:16761</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16856' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16856'>CHEBI:16856</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16973' target='_blank' title='Go to CHEBI to get more informations about CHEBI:16973'>CHEBI:16973</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:17230' target='_blank' title='Go to CHEBI to get more informations about CHEBI:17230'>CHEBI:17230</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:18295' target='_blank' title='Go to CHEBI to get more informations about CHEBI:18295'>CHEBI:18295</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:21241' target='_blank' title='Go to CHEBI to get more informations about CHEBI:21241'>CHEBI:21241</a> (node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a>)</p></li>
# <li><p class="paragraph"><a href='https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:22333' target='_blank' title='Go to CHEBI to get more informations about CHEBI:22333'>CHEBI:22333</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li></ul><p class="paragraph">And other 2.56K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 8 node tuples in the graph, involving a total of 16 nodes (0.03%) and 8 edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0003000' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003000'>RO:0003000</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0003001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003001'>RO:0003001</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002321' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002321'>RO:0002321</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002322' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002322'>RO:0002322</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002005' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002005'>RO:0002005</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002134' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002134'>RO:0002134</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001019' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001019'>RO:0001019</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001015' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001015'>RO:0001015</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node types <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_acid_of'>OBO:chebi#is_conjugate_acid_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_base_of'>OBO:chebi#is_conjugate_base_of</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BSPO_0000098' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000098'>BSPO:0000098</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BSPO_0000102' target='_blank' title='Go to Biological Spatial Ontology to get more informations about BSPO:0000102'>BSPO:0000102</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/BFO_0000066' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000066'>BFO:0000066</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/BFO_0000067' target='_blank' title='Go to Basic Formal Ontology to get more informations about BFO:0000067'>BFO:0000067</a> (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 3 isomorphic node groups in the graph, involving a total of 7 nodes (0.01%) and 37 edges (0.02%), with the largest one involving 3 nodes and 15 edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 3 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0011314' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011314'>UBERON:0011314</a>, <a href='http://purl.obolibrary.org/obo/UBERON_0011306' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011306'>UBERON:0011306</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0011313' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0011313'>UBERON:0011313</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 6 and node types <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0003952' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0003952'>UBERON:0003952</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0003953' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0003953'>UBERON:0003953</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 5 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>): <a href='http://purl.obolibrary.org/obo/UBERON_0013773' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0013773'>UBERON:0013773</a> and <a href='http://purl.obolibrary.org/obo/UBERON_0013772' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0013772'>UBERON:0013772</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected  a single tree in the graph, involving a total of 10 nodes (0.02%) and 18 edges.</p><ul class="large-columns"><li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002342' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002342'>RO:0002342</a> (degree 2), and containing 10 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/RO_0002021' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002021'>RO:0002021</a>, <a href='http://purl.obolibrary.org/obo/RO_0002344' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002344'>RO:0002344</a> (degree 4), <a href='http://purl.obolibrary.org/obo/RO_0002479' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002479'>RO:0002479</a> (degree 3), <a href='http://purl.obolibrary.org/obo/RO_0002337' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002337'>RO:0002337</a> and <a href='http://purl.obolibrary.org/obo/RO_0002338' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002338'>RO:0002338</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 1.41K dendritic trees in the graph, involving a total of 18.43K nodes (32.33%) and 36.86K edges (18.76%), with the largest one involving 245 nodes and 490 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0002960' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002960'>HP:0002960</a> (degree 8), and containing 245 nodes, with a maximal depth of 5, which are <a href='http://purl.obolibrary.org/obo/HP_0002725' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002725'>HP:0002725</a>, <a href='http://purl.obolibrary.org/obo/HP_0030057' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030057'>HP:0030057</a> (degree 162), <a href='http://purl.obolibrary.org/obo/HP_0032265' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032265'>HP:0032265</a>, <a href='http://purl.obolibrary.org/obo/HP_0002923' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002923'>HP:0002923</a> and <a href='http://purl.obolibrary. ...
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0005584' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005584'>MP:0005584</a> (degree 44), and containing 188 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/MP_0005581' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0005581'>MP:0005581</a> (degree 3), <a href='http://purl.obolibrary.org/obo/MP_0011583' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011583'>MP:0011583</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0011586' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011586'>MP:0011586</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0011589' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011589'>MP:0011589</a> (degree 4) and <a href='http://purl.obolibrary.org/obo/MP_0011595' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0011595'>MP:0011595</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (207 edges, 61.24%) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (131 edges, 38.76%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0003009' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0003009'>MP:0003009</a> (degree 7), and containing 160 nodes, with a maximal depth of 5, which are <a href='http://purl.obolibrary.org/obo/MP_0008555' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008555'>MP:0008555</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008556' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008556'>MP:0008556</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008568' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008568'>MP:0008568</a> (degree 20), N764086610974445e976b96248ef33097 and <a href='http://purl.obolibrary.org/obo/MP_0008557' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008557'>MP:0008557</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (163 edges, 51.58%) and <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (153 edges, 48.42%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/MP_0008588' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008588'>MP:0008588</a> (degree 21), and containing 134 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/MP_0008589' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008589'>MP:0008589</a> (degree 6), <a href='http://purl.obolibrary.org/obo/MP_0008590' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008590'>MP:0008590</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008595' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008595'>MP:0008595</a> (degree 4), <a href='http://purl.obolibrary.org/obo/MP_0008598' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008598'>MP:0008598</a> (degree 4) and <a href='http://purl.obolibrary.org/obo/MP_0008601' target='_blank' title='Go to Mammalian Phenotype Ontology to get more informations about MP:0008601'>MP:0008601</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/has_part.html' target='_blank' title='Go to BioLink to get more informations about biolink:has_part'>biolink:has_part</a> (134 edges, 53.82%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (115 edges, 46.18%).</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000504' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000504'>HP:0000504</a> (degree 16), and containing 131 nodes, with a maximal depth of 6, which are <a href='http://purl.obolibrary.org/obo/HP_0000505' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000505'>HP:0000505</a> (degree 5), <a href='http://purl.obolibrary.org/obo/HP_0000622' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000622'>HP:0000622</a>, <a href='http://purl.obolibrary.org/obo/HP_0011514' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011514'>HP:0011514</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0012047' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012047'>HP:0012047</a> and <a href='http://purl.obolibrary.org/obo/HP_0012508' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012508'>HP:0012508</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0012823' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012823'>HP:0012823</a> (degree 13), and containing 128 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/HP_0003812' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003812'>HP:0003812</a>, <a href='http://purl.obolibrary.org/obo/HP_0012824' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012824'>HP:0012824</a> (degree 6), <a href='http://purl.obolibrary.org/obo/HP_0012830' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012830'>HP:0012830</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0025204' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025204'>HP:0025204</a> (degree 25) and <a href='http://purl.obolibrary.org/obo/HP_0025254' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025254'>HP:0025254</a> (degree 7). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 1.40K dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Stars</h4><p class="paragraph">A star is a tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with a high degree. We have detected  a single star in the graph, involving a total of 3 nodes and 4 edges.</p><ul class="large-columns"><li><p class="paragraph">Star starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0015006' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015006'>RO:0015006</a> (degree 2), and containing 3 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/RO_0015007' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015007'>RO:0015007</a> and <a href='http://purl.obolibrary.org/obo/RO_0015008' target='_blank' title='Go to Relation Ontology to get more informations about RO:0015008'>RO:0015008</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 866 dendritic stars in the graph, involving a total of 2.66K nodes (4.67%) and 5.33K edges (2.71%), with the largest one involving 17 nodes and 34 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001028' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001028'>HP:0001028</a> (degree 26), and containing 17 nodes, with a maximal depth of 1, which are <a href='http:// ...
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001878' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001878'>HP:0001878</a> (degree 17), and containing 15 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0001930' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001930'>HP:0001930</a>, <a href='http://purl.obolibrary.org/obo/HP_0001937' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001937'>HP:0001937</a>, <a href='http://purl.obolibrary.org/obo/HP_0004802' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004802'>HP:0004802</a>, <a href='http://purl.obolibrary.org/obo/HP_0004804' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004804'>HP:0004804</a> and <a href='http://purl.obolibrary.org/obo/HP_0004814' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004814'>HP:0004814</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/MAXO_0000665' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000665'>OBO:MAXO_0000665</a> (degree 26), and containing 13 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/MAXO_0000666' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000666'>OBO:MAXO_0000666</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000670' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000670'>OBO:MAXO_0000670</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000671' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000671'>OBO:MAXO_0000671</a>, <a href='http://purl.obolibrary.org/obo/MAXO_0000676' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000676'>OBO:MAXO_0000676</a> and <a href='http://purl.obolibrary.org/obo/MAXO_0000697' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:MAXO_0000697'>OBO:MAXO_0000697</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0006101' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0006101'>HP:0006101</a> (degree 13), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0001233' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001233'>HP:0001233</a>, <a href='http://purl.obolibrary.org/obo/HP_0006097' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0006097'>HP:0006097</a>, <a href='http://purl.obolibrary.org/obo/HP_0010492' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010492'>HP:0010492</a>, <a href='http://purl.obolibrary.org/obo/HP_0010692' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010692'>HP:0010692</a> and <a href='http://purl.obolibrary.org/obo/HP_0010704' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010704'>HP:0010704</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0011038' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011038'>HP:0011038</a> (degree 13), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0004727' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004727'>HP:0004727</a>, <a href='http://purl.obolibrary.org/obo/HP_0005571' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005571'>HP:0005571</a>, <a href='http://purl.obolibrary.org/obo/HP_0005579' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005579'>HP:0005579</a>, <a href='http://purl.obolibrary.org/obo/HP_0008666' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008666'>HP:0008666</a> and <a href='http://purl.obolibrary.org/obo/HP_0033759' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033759'>HP:0033759</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0001770' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001770'>HP:0001770</a> (degree 14), and containing 11 nodes, with a maximal depth of 1, which are <a href='http://purl.obolibrary.org/obo/HP_0001459' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001459'>HP:0001459</a>, <a href='http://purl.obolibrary.org/obo/HP_0004691' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004691'>HP:0004691</a>, <a href='http://purl.obolibrary.org/obo/HP_0004692' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004692'>HP:0004692</a>, <a href='http://purl.obolibrary.org/obo/HP_0009779' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0009779'>HP:0009779</a> and <a href='http://purl.obolibrary.org/obo/HP_0010711' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010711'>HP:0010711</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 860 dendritic stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic tendril stars</h4><p class="paragraph">A dendritic tendril star is a dendritic tree with a depth greater than one, where the arms of the star are tendrils. We have detected 557 dendritic tendril stars in the graph, involving a total of 2.04K nodes (3.58%) and 4.08K edges (2.08%), with the largest one involving 13 nodes and 26 edges. The detected dendritic tendril stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/PATO_0000052' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0000052'>PATO:0000052</a> (degree 26), and containing 13 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/PATO_0000405' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0000405'>PATO:0000405</a>, <a href='http://purl.obolibrary.org/obo/PATO_0000617' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0000617'>PATO:0000617</a>, <a href='http://purl.obolibrary.org/obo/PATO_0000967' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0000967'>PATO:0000967</a>, <a href='http://purl.obolibrary.org/obo/PATO_0001481' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001481'>PATO:0001481</a> and <a href='http://purl.obolibrary.org/obo/PATO_0001878' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001878'>PATO:0001878</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0002031' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002031'>HP:0002031</a> (degree 19), and containing 12 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0002040' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002040'>HP:0002040</a>, <a href='http://purl.obolibrary.org/obo/HP_0005203' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005203'>HP:0005203</a>, <a href='http://purl.obolibrary.org/obo/HP_0010450' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0010450'>HP:0010450</a>, <a href='http://purl.obolibrary.org/obo/HP_0011128' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011128'>HP:0011128</a> and <a href='http://purl.obolibrary.org/obo/HP_0012859' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012859'>HP:0012859</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0031331' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031331'>HP:0031331</a> (degree 12), and containing 11 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0031319' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031319'>HP:0031319</a>, <a href='http://purl.obolibrary.org/obo/HP_0031320' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031320'>HP:0031320</a>, <a href='http://purl.obolibrary.org/obo/HP_0031332' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031332'>HP:0031332</a>, <a href='http://purl.obolibrary.org/obo/HP_0031333' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031333'>HP:0031333</a> and <a href='http://purl.obolibrary.org/obo/HP_0031334' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031334'>HP:0031334</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0009811' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0009811'>HP:0009811</a> (degree 20), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0002967' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002967'>HP:0002967</a>, <a href='http://purl.obolibrary.org/obo/HP_0003102' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003102'>HP:0003102</a>, <a href='http://purl.obolibrary.org/obo/HP_0003941' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003941'>HP:0003941</a>, <a href='http://purl.obolibrary.org/obo/HP_0003942' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003942'>HP:0003942</a> and <a href='http://purl.obolibrary.org/obo/HP_0003943' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003943'>HP:0003943</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0012440' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012440'>HP:0012440</a> (degree 14), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0001408' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001408'>HP:0001408</a>, <a href='http://purl.obolibrary.org/obo/HP_0002613' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002613'>HP:0002613</a>, <a href='http://purl.obolibrary.org/obo/HP_0005230' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0005230'>HP:0005230</a>, <a href='http://purl.obolibrary.org/obo/HP_0006560' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0006560'>HP:0006560</a> and <a href='http://purl.obolibrary.org/obo/HP_0025154' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0025154'>HP:0025154</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0003170' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003170'>HP:0003170</a> (degree 11), and containing 10 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0003179' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003179'>HP:0003179</a>, <a href='http://purl.obolibrary.org/obo/HP_0003180' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003180'>HP:0003180</a>, <a href='http://purl.obolibrary.org/obo/HP_0003182' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003182'>HP:0003182</a>, <a href='http://purl.obolibrary.org/obo/HP_0003274' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003274'>HP:0003274</a> and <a href='http://purl.obolibrary.org/obo/HP_0008807' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0008807'>HP:0008807</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 551 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Free-floating chains</h4><p class="paragraph">A free-floating chain is a tree with maximal degree two. We have detected  a single free-floating chain in the graph, involving a total of 4 nodes and 6 edges.</p><ul class="large-columns"><li><p class="paragraph">Free-floating chain starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002564' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002564'>RO:0002564</a> (degree 2), and containing 4 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/RO_0002481' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002481'>RO:0002481</a>, <a href='http://purl.obolibrary.org/obo/RO_0002563' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002563'>RO:0002563</a> and <a href='http://purl.obolibrary.org/obo/RO_0002464' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002464'>RO:0002464</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 4.84K tendrils in the graph, involving a total of 4.94K nodes (8.67%) and 9.89K edges (5.03%), with the largest one involving 8 nodes and 16 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8457' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8457'>NCBITaxon:8457</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=32561' targ ...
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6231' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6231'>NCBITaxon:6231</a> (degree 3), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=119089' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:119089'>NCBITaxon:119089</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6236' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6236'>NCBITaxon:6236</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301116' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301116'>NCBITaxon:2301116</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301119' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301119'>NCBITaxon:2301119</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=55879' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:55879'>NCBITaxon:55879</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4890' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4890'>NCBITaxon:4890</a> (degree 3), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=451866' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:451866'>NCBITaxon:451866</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=147554' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:147554'>NCBITaxon:147554</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=34346' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:34346'>NCBITaxon:34346</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4894' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4894'>NCBITaxon:4894</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4895' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4895'>NCBITaxon:4895</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=147537' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:147537'>NCBITaxon:147537</a> (degree 3), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4891' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4891'>NCBITaxon:4891</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4892' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4892'>NCBITaxon:4892</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4893' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4893'>NCBITaxon:4893</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4930' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4930'>NCBITaxon:4930</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=4932' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:4932'>NCBITaxon:4932</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000080' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000080'>HP:0000080</a> (degree 9), and containing 4 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/HP_0033337' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033337'>HP:0033337</a>, <a href='http://purl.obolibrary.org/obo/HP_0031515' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031515'>HP:0031515</a>, <a href='http://purl.obolibrary.org/obo/HP_0033338' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0033338'>HP:0033338</a> and <a href='http://purl.obolibrary.org/obo/HP_0031516' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0031516'>HP:0031516</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=142796' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:142796'>NCBITaxon:142796</a> (degree 3), and containing 4 nodes, with a maximal depth of 4, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=33083' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:33083'>NCBITaxon:33083</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2058949' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2058949'>NCBITaxon:2058949</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2058185' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2058185'>NCBITaxon:2058185</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=5782' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:5782'>NCBITaxon:5782</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 4.84K tendrils.</p></div>

# %% [markdown]
# ### Overlap between ontologies and KGs
#
# This magic line of code is performing an **intersection operation** between the `kgcovid19` and `hp_or_mp` graphs. The intersection operation is represented by the `and` (`&`) symbol, and it returns a new graph that contains only the nodes and edges that are present in both of the input graphs. In this case, the `kgcovid19` graph represents a knowledge graph that integrates biomedical data related to the COVID-19 pandemic, while the `hp_or_mp` graph represents the union of the Human Phenotype Ontology (HPO) and Mammalian Phenotype Ontology (MPO), which are standardized vocabularies for describing human and mammalian phenotypes, respectively. By performing an intersection operation between these two graphs, we are effectively extracting the portion of the COVID-19 knowledge graph that is related to human and mammalian phenotypes.

# %%
# %%time
kgcovid19_and_hp_or_mp = kgcovid19 & hp_or_mp
# Out:
# CPU times: user 39 s, sys: 5.51 s, total: 44.5 s
# Wall time: 2.05 s

# %% [markdown]
# Let's take a look at how this looks:

# %%
kgcovid19_and_hp_or_mp
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>(KGCOVID19 & (HP | MP))</h2><p class="paragraph">The undirected multigraph (KGCOVID19 & (HP | MP)) has 601.57K heterogeneous nodes and 52.88K heterogeneous edges. The graph contains 573.32K connected components (of which 573.27K are disconnected nodes), with the largest one containing 15.93K nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 83.69MB and 5.24MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 453, the mode degree is 0, the mean degree is 0.18 and the node degree median is 0.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='http://purl.obolibrary.org/obo/CARO_0000000' target='_blank' title='Go to Common Anatomy Reference Ontology to get more informations about CARO:0000000'>CARO:0000000</a> (degree 453 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>), <a href='http://purl.obolibrary.org/obo/UBERON_0004120' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0004120'>UBERON:0004120</a> (degree 256 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>), <a href='http://purl.obolibrary.org/obo/UBERON_0010314' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0010314'>UBERON:0010314</a> (degree 205 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>), <a href='http://purl.obolibrary.org/obo/UBERON_0004121' target='_blank' title='Go to Uberon multi-species anatomy ontology to get more informations about UBERON:0004121'>UBERON:0004121</a> (degree 195 and node type <a href='https://biolink.github.io/biolink-model/docs/AnatomicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:AnatomicalEntity'>biolink:AnatomicalEntity</a>) and <a href='http://purl.obolibrary.org/obo/CARO_0000003' target='_blank' title='Go to Common Anatomy Reference Ontology to get more informations about CARO:0000003'>CARO:0000003</a> (degree 118 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink ...
# <li><p class="paragraph">:CS (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:DIP-24261N (node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>)</p></li>
# <li><p class="paragraph">:DQ811788.1 (node type <a href='https://biolink.github.io/biolink-model/docs/RNA.html' target='_blank' title='Go to BioLink to get more informations about biolink:RNA'>biolink:RNA</a>)</p></li>
# <li><p class="paragraph">:DSP0001 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000004 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000005 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000006 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000007 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000008 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000009 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000010 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000011 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000013 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000014 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li></ul><p class="paragraph">And other 573.25K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 17 node tuples in the graph, involving a total of 34 nodes and 17 edges (0.02%). The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://www.sequenceontology.org/browser/current_svn/term/SO:0000704' target='_blank' title='Go to Sequence Ontology to get more informations about SO:0000704'>SO:0000704</a> (node type <a href='https://biolink.github.io/biolink-model/docs/SequenceFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:SequenceFeature'>biolink:SequenceFeature</a>) and <a href='http://www.sequenceontology.org/browser/current_svn/term/SO:0001217' target='_blank' title='Go to Sequence Ontology to get more informations about SO:0001217'>SO:0001217</a> (node type <a href='https://biolink.github.io/biolink-model/docs/SequenceFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:SequenceFeature'>biolink:SequenceFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0003000' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003000'>RO:0003000</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0003001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003001'>RO:0003001</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002321' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002321'>RO:0002321</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002322' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002322'>RO:0002322</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002005' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002005'>RO:0002005</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002134' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002134'>RO:0002134</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001019' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001019'>RO:0001019</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001015' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001015'>RO:0001015</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>, <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_acid_of'>OBO:chebi#is_conjugate_acid_of</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of' target='_blank' title='Go to Open Biomedical Ontology to get more informations about OBO:chebi#is_conjugate_base_of'>OBO:chebi#is_conjugate_base_of</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0030327' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030327'>HP:0030327</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0030328' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030328'>HP:0030328</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0009058' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0009058'>HP:0009058</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0012240' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012240'>HP:0012240</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0003959' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003959'>HP:0003959</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0003977' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003977'>HP:0003977</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0003743' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003743'>HP:0003743</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0003744' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0003744'>HP:0003744</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0001470' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001470'>HP:0001470</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0001475' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001475'>HP:0001475</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/HP_0000268' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000268'>HP:0000268</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0030799' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030799'>HP:0030799</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://amigo.geneontology.org/amigo/term/GO:1904014' target='_blank' title='Go to Gene Ontology to get more informations about GO:1904014'>GO:1904014</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a>) and <a href='http://amigo.geneontology.org/amigo/term/GO:1904015' target='_blank' title='Go to Gene Ontology to get more informations about GO:1904015'>GO:1904015</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://amigo.geneontology.org/amigo/term/GO:0002396' target='_blank' title='Go to Gene Ontology to get more informations about GO:0002396'>GO:0002396</a> (node type <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a>) and <a href='http://amigo.geneontology.org/amigo/term/GO:0002399' target='_blank' title='Go to Gene Ontology to get more informations about GO:0002399'>GO:0002399</a> (node types <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLink to get more informations about biolink:BiologicalProcess'>biolink:BiologicalProcess</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li></ul><p class="paragraph">And other 2 node tuples.</p><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected 6 trees in the graph, involving a total of 106 nodes (0.02%) and 200 edges (0.19%), with the largest one involving 66 nodes and 130 edges. The detected trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0500184' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500184'>HP:0500184</a> (degree 13), and containing 66 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/HP_0500183' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500183'>HP:0500183</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0500185' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500185'>HP:0500185</a> (degree 4), <a href='http://purl.obolibrary.org/obo/HP_0500195' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500195'>HP:0500195</a> (degree 4), <a href='http://purl.obolibrary.org/obo/HP_0500205' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500205'>HP:0500205</a> (degree 5) and <a href='http://purl.obolibrary.org/obo/HP_0500214' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500214'>HP:0500214</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/PATO_0001404' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001404'>PATO:0001404</a> (degree 3), and containing 15 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/PATO_0001396' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001396'>PATO:0001396</a> (degree 4), <a href='http://purl.obolibrary.org/obo/PATO_0001405' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001405'>PATO:0001405</a>, <a href='http://purl.obolibrary.org/obo/PATO_0002505' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0002505'>PATO:0002505</a> (degree 3), <a href='http://purl.obolibrary.org/obo/PATO_0001374' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001374'>PATO:0001374</a> and <a href='http://purl.obolibrary.org/obo/PATO_0001397' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001397'>PATO:0001397</a> (degree 4). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (14 nodes) and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (14 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002342' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002342'>RO:0002342</a> (degree 2), and containing 10 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/RO_0002021' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002021'>RO:0002021</a>, <a href='http://purl.obolibrary.org/obo/RO_0002344' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002344'>RO:0002344</a> (degree 4), <a href='http://purl.obolibrary.org/obo/RO_0002479' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002479'>RO:0002479</a> (degree 3), <a href='http://purl.obolibrary.org/obo/RO_0002337' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002337'>RO:0002337</a> and <a href='http://purl.obolibrary.org/obo/RO_0002338' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002338'>RO:0002338</a>. Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (9 nodes) and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (9 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000244' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000244'>HP:0000244</a> (degree 2 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), and containing 5 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0000248' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000248'>HP:0000248</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0000262' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000262'>HP:0000262</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0004487' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0004487'>HP:0004487</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0000263' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000263'>HP:0000263</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a> (4 nodes) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (2 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0012269' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012269'>HP:0012269</a> (degree 2 and node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), and containing 5 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/HP_0009051' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0009051'>HP:0009051</a> (degree 3 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0012270' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012270'>HP:0012270</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0030231' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030231'>HP:0030231</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0030232' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030232'>HP:0030232</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a> (4 nodes) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (2 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/MPATH_603' target='_blank' title='Go to Mouse pathology ontology to get more informations about MPATH:603'>MPATH:603</a> (degree 2), and containing 5 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/MPATH_0' target='_blank' title='Go to Mouse pathology ontology to get more informations about MPATH:0'>MPATH:0</a>, <a href='http://purl.obolibrary.org/obo/MPATH_607' target='_blank' title='Go to Mouse pathology ontology to get more informations about MPATH:607'>MPATH:607</a>, <a href='http://purl.obolibrary.org/obo/MPATH_1000' target='_blank' title='Go to Mouse pathology ontology to get more informations about MPATH:1000'>MPATH:1000</a> and <a href='http://purl.obolibrary.org/obo/MPATH_608' target='_blank' title='Go to Mouse pathology ontology to get more informations about MPATH:608'>MPATH:608</a>. Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (4 nodes) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (4 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 530 dendritic trees in the graph, involving a total of 7.93K nodes (1.32%) and 15.86K edges (15.00%), with the largest one involving 221 nodes and 442 edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000118' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000118'>HP:0000118</a> (degree 24), and containing 221 nodes, with a maximal depth of 7, which are <a href='http://purl.obolibrary.org/obo/HP_0000001' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000001'>HP:0000001</a> (degree 6), <a href='http://purl.obolibrary.org/obo/HP_0000005' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000005'>HP:0000005</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0012823' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012823'>HP:0012823</a> (degree 13), <a href='http://purl.obolibrary.org/obo/HP_0032223' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032223'>HP:0032223</a> (degree 3) and <a href='http://purl.obolibrary.org/obo/HP_0032443' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032443'>HP:0032443</a> (degree 9). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0002960' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002960'>HP:0002960</a> (degree 8 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), and containing 154 nodes, with a maximal depth of 6, which are <a href='http://purl.obolibrary.org/obo/HP_0001973' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001973'>HP:0001973</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0002725' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0002725'>HP:0002725</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0030057' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0030057'>HP:0030057</a> (degree 101 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0032265' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032265'>HP:0032265</a> (node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0001873' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0001873'>HP:0001873</a> (degree 9 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a> (154 nodes, 0.03%) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (27 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs ...
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000504' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000504'>HP:0000504</a> (degree 16 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), and containing 131 nodes, with a maximal depth of 6, which are <a href='http://purl.obolibrary.org/obo/HP_0000505' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000505'>HP:0000505</a> (degree 5 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0000622' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000622'>HP:0000622</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0011514' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0011514'>HP:0011514</a> (degree 3 and node type <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>), <a href='http://purl.obolibrary.org/obo/HP_0012047' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012047'>HP:0012047</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>) and <a href='http://purl.obolibrary.org/obo/HP_0012508' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012508'>HP:0012508</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a> (131 nodes, 0.02%) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (30 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/ ...
# ...
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='http://purl.obolibrary.org/obo/RO_0002564' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002564'>RO:0002564</a> (degree 2), and containing 4 nodes, with a maximal depth of 2, which are <a href='http://purl.obolibrary.org/obo/RO_0002481' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002481'>RO:0002481</a>, <a href='http://purl.obolibrary.org/obo/RO_0002563' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002563'>RO:0002563</a> and <a href='http://purl.obolibrary.org/obo/RO_0002464' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002464'>RO:0002464</a>. Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (3 nodes) and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (3 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subPropertyOf.html' target='_blank' title='Go to BioLink to get more informations about biolink:subPropertyOf'>biolink:subPropertyOf</a>.</p></li></ul><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 709 tendrils in the graph, involving a total of 814 nodes (0.14%) and 1.63K edges (1.54%), with the largest one involving 9 nodes and 18 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314146' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314146'>NCBITaxon:314146</a> (degree 4), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314147' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314147'>NCBITaxon:314147</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9989' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9989'>NCBITaxon:9989</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1963758' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1963758'>NCBITaxon:1963758</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=337687' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:337687'>NCBITaxon:337687</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=10066' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:10066'>NCBITaxon:10066</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1206794' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1206794'>NCBITaxon:1206794</a> (degree 3), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6231' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6231'>NCBITaxon:6231</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=119089' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:119089'>NCBITaxon:119089</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6236' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6236'>NCBITaxon:6236</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301116' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301116'>NCBITaxon:2301116</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301119' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301119'>NCBITaxon:2301119</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9443' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9443'>NCBITaxon:9443</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=376913' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:376913'>NCBITaxon:376913</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314293' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314293'>NCBITaxon:314293</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9526' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9526'>NCBITaxon:9526</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314295' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314295'>NCBITaxon:314295</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9604' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9604'>NCBITaxon:9604</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (15 edges, 65.22%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (8 edges, 34.78%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8457' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8457'>NCBITaxon:8457</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=32561' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:32561'>NCBITaxon:32561</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1329799' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1329799'>NCBITaxon:1329799</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8492' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8492'>NCBITaxon:8492</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=436486' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:436486'>NCBITaxon:436486</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=436489' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:436489'>NCBITaxon:436489</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1437010' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1437010'>NCBITaxon:1437010</a> (degree 4), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314145' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314145'>NCBITaxon:314145</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=91561' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:91561'>NCBITaxon:91561</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2653789' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2653789'>NCBITaxon:2653789</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9721' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9721'>NCBITaxon:9721</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9722' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9722'>NCBITaxon:9722</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (9 edges, 64.29%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (5 edges, 35.71%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='http://amigo.geneontology.org/amigo/term/GO:0005515' target='_blank' title='Go to Gene Ontology to get more informations about GO:0005515'>GO:0005515</a> (degree 8 and node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>), and containing 4 nodes, with a maximal depth of 4, which are <a href='http://amigo.geneontology.org/amigo/term/GO:0008134' target='_blank' title='Go to Gene Ontology to get more informations about GO:0008134'>GO:0008134</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>), <a href='http://amigo.geneontology.org/amigo/term/GO:0140297' target='_blank' title='Go to Gene Ontology to get more informations about GO:0140297'>GO:0140297</a> (node type <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>), <a href='http://amigo.geneontology.org/amigo/term/GO:0061629' target='_blank' title='Go to Gene Ontology to get more informations about GO:0061629'>GO:0061629</a> (node type <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>) and <a href='http://amigo.geneontology.org/amigo/term/GO:0051059' target='_blank' title='Go to Gene Ontology to get more informations about GO:0051059'>GO:0051059</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a>). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/MolecularActivity.html' target='_blank' title='Go to BioLink to get more informations about biolink:MolecularActivity'>biolink:MolecularActivity</a> (4 nodes) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (2 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 703 tendrils.</p></div>

# %% [markdown]
# ### Merging with a citation graph
#
# The following line of code merges the PubMed citation graph with the KGCOVID19 knowledge graph and the Human Phenotype Ontology (HPO) and Mammalian Phenotype Ontology (MPO). This is useful because the PubMed graph contains articles that are also present in the other three graphs, and merging them will bring together all of the important topological information into one graph. The resulting graph will contain information about the relationships between articles in the PubMed database, as well as the relationships between genes, proteins, and other entities in the KGCOVID19 knowledge graph and the HPO and MPO ontologies. This will allow researchers to more easily explore and analyze the relationships between these datasets, and to better understand the underlying causes of diseases and conditions.

# %%
# %%time
pubmed_or_kgcovid19_and_hp_or_mp = pubmed | kgcovid19_and_hp_or_mp
# Out:
# CPU times: user 17min 46s, sys: 54min 9s, total: 1h 11min 55s
# Wall time: 3min 16s

# %% [markdown]
# Let's check out its graph report:

# %%
pubmed_or_kgcovid19_and_hp_or_mp
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>(PubMed | (KGCOVID19 & (HP | MP)))</h2><p class="paragraph">The undirected multigraph (PubMed | (KGCOVID19 & (HP | MP))) has 22.19M heterogeneous nodes and 249.23M heterogeneous edges. The graph contains 590.07K connected components (of which 573.99K are disconnected nodes), with the largest one containing 21.55M nodes and the smallest one containing a single node. The RAM requirements for the nodes and edges data structures are 2.33GB and 2.17GB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 54.93K, the mode degree is 1, the mean degree is 22.46 and the node degree median is 8.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='https://pubmed.ncbi.nlm.nih.gov/5432063/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5432063'>PMID:5432063</a> (degree 54.93K and unknown node type), <a href='https://pubmed.ncbi.nlm.nih.gov/11846609/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11846609'>PMID:11846609</a> (degree 54.17K and unknown node type), <a href='https://pubmed.ncbi.nlm.nih.gov/14907713/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14907713'>PMID:14907713</a> (degree 53.59K and unknown node type), <a href='https://pubmed.ncbi.nlm.nih.gov/942051/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:942051'>PMID:942051</a> (degree 46.13K and unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/2231712/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2231712'>PMID:2231712</a> (degree 28.32K and unknown node type).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 20 node types, of which the 10 most common are <a href='https://biolink.github.io/biolink-model/docs/Publication.html' target='_blank' title='Go to BioLink to get more informations about biolink:Publication'>biolink:Publication</a> (190.05K nodes, 0.86%), <a href='https://biolink.github.io/biolink-model/docs/ChemicalSubstance.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalSubstance'>biolink:ChemicalSubstance</a> (144.76K nodes, 0.65%), <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (73.50K nodes, 0.33%), <a href='https://biolink.github.io/biolink-model/docs/Drug.html' target='_blank' title='Go to BioLink to get more informations about biolink:Drug'>biolink:Drug</a> (40.65K nodes, 0.18%), <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (33.24K nodes, 0.15%), <a href='https://biolink.github.io/biolink-model/docs/BiologicalProcess.html' target='_blank' title='Go to BioLin ...
# <li><p class="paragraph">:CS (node type <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>)</p></li>
# <li><p class="paragraph">:DIP-24261N (node type <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a>)</p></li>
# <li><p class="paragraph">:DQ811788.1 (node type <a href='https://biolink.github.io/biolink-model/docs/RNA.html' target='_blank' title='Go to BioLink to get more informations about biolink:RNA'>biolink:RNA</a>)</p></li>
# <li><p class="paragraph">:DSP0001 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000004 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000005 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000006 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000007 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000008 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000009 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000010 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000011 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000013 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li>
# <li><p class="paragraph">:DSPEC000014 (node type <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>)</p></li></ul><p class="paragraph">And other 573.25K singleton nodes.</p><h4 style="margin: 1em 0 0 0;">Singleton nodes with self-loops</h4><p class="paragraph">A singleton node with self-loops is a node disconnected from all other nodes except itself. We have detected 725 singleton nodes with self-loops in the graph, involving a total of 725 nodes and 725 edges. The detected singleton nodes with self-loops are:</p><ul class="small-columns"><li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/10977844/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10977844'>PMID:10977844</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/11025537/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11025537'>PMID:11025537</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/11025538/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11025538'>PMID:11025538</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/12432145/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12432145'>PMID:12432145</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/1286377/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1286377'>PMID:1286377</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/1286390/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1286390'>PMID:1286390</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/14623844/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14623844'>PMID:14623844</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/16027968/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:16027968'>PMID:16027968</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/17006575/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17006575'>PMID:17006575</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/17370136/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17370136'>PMID:17370136</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/17422322/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17422322'>PMID:17422322</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/17422334/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17422334'>PMID:17422334</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/17882317/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:17882317'>PMID:17882317</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/18311354/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18311354'>PMID:18311354</a> (unknown node type)</p></li>
# <li><p class="paragraph"><a href='https://pubmed.ncbi.nlm.nih.gov/18490645/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18490645'>PMID:18490645</a> (unknown node type)</p></li></ul><p class="paragraph">And other 710 singleton nodes with self-loops.</p><h4 style="margin: 1em 0 0 0;">Node tuples</h4><p class="paragraph">A node tuple is a connected component composed of two nodes. We have detected 11.81K node tuples in the graph, involving a total of 23.62K nodes (0.11%) and 11.81K edges. The detected node tuples are:</p><ul class="medium-columns"><li><p class="paragraph">Node tuple containing the nodes <a href='http://www.sequenceontology.org/browser/current_svn/term/SO:0000704' target='_blank' title='Go to Sequence Ontology to get more informations about SO:0000704'>SO:0000704</a> (node type <a href='https://biolink.github.io/biolink-model/docs/SequenceFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:SequenceFeature'>biolink:SequenceFeature</a>) and <a href='http://www.sequenceontology.org/browser/current_svn/term/SO:0001217' target='_blank' title='Go to Sequence Ontology to get more informations about SO:0001217'>SO:0001217</a> (node type <a href='https://biolink.github.io/biolink-model/docs/SequenceFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:SequenceFeature'>biolink:SequenceFeature</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0003000' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003000'>RO:0003000</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0003001' target='_blank' title='Go to Relation Ontology to get more informations about RO:0003001'>RO:0003001</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002321' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002321'>RO:0002321</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002322' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002322'>RO:0002322</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0002005' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002005'>RO:0002005</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0002134' target='_blank' title='Go to Relation Ontology to get more informations about RO:0002134'>RO:0002134</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001018' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001018'>RO:0001018</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001019' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001019'>RO:0001019</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='http://purl.obolibrary.org/obo/RO_0001015' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001015'>RO:0001015</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>) and <a href='http://purl.obolibrary.org/obo/RO_0001025' target='_blank' title='Go to Relation Ontology to get more informations about RO:0001025'>RO:0001025</a> (node types <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a>, <a href='https://biolink.github.io/biolink-model/docs/Protein.html' target='_blank' title='Go to BioLink to get more informations about biolink:Protein'>biolink:Protein</a> and <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a>).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9677233/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9677233'>PMID:9677233</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9880297/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9880297'>PMID:9880297</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9657816/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9657816'>PMID:9657816</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9888925/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9888925'>PMID:9888925</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9640527/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9640527'>PMID:9640527</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9805154/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9805154'>PMID:9805154</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/961939/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:961939'>PMID:961939</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/961941/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:961941'>PMID:961941</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9612581/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9612581'>PMID:9612581</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9721409/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9721409'>PMID:9721409</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9607534/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9607534'>PMID:9607534</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9849343/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9849343'>PMID:9849343</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9589122/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9589122'>PMID:9589122</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9875260/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9875260'>PMID:9875260</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9582163/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9582163'>PMID:9582163</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9721133/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9721133'>PMID:9721133</a> (unknown node type).</p></li>
# <li><p class="paragraph">Node tuple containing the nodes <a href='https://pubmed.ncbi.nlm.nih.gov/9559199/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9559199'>PMID:9559199</a> (unknown node type) and <a href='https://pubmed.ncbi.nlm.nih.gov/9765725/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9765725'>PMID:9765725</a> (unknown node type).</p></li></ul><p class="paragraph">And other 11.79K node tuples.</p><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic groups are nodes with exactly the same neighbours and node types (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 2.01K isomorphic node groups in the graph, involving a total of 4.70K nodes (0.02%) and 48.33K edges, with the largest one involving 146 nodes and 2.24K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 10 nodes (degree 224 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/28766776/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766776'>PMID:28766776</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766778/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766778'>PMID:28766778</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766787/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766787'>PMID:28766787</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766785/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766785'>PMID:28766785</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28766772/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28766772'>PMID:28766772</a> and other 5.</p></li>
# <li><p class="paragraph">Group with 96 nodes (degree 8 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/34486051/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34486051'>PMID:34486051</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34514329/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34514329'>PMID:34514329</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34734111/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34734111'>PMID:34734111</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34486034/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34486034'>PMID:34486034</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34483112/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34483112'>PMID:34483112</a> and other 91.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 365 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/34589512/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34589512'>PMID:34589512</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34790692/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34790692'>PMID:34790692</a>.</p></li>
# <li><p class="paragraph">Group with 146 nodes (degree 5 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/11967511/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:11967511'>PMID:11967511</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/2151560/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2151560'>PMID:2151560</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/9854718/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9854718'>PMID:9854718</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12575025/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12575025'>PMID:12575025</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/1829379/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1829379'>PMID:1829379</a> and other 141.</p></li>
# <li><p class="paragraph">Group with 32 nodes (degree 14 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/29637372/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637372'>PMID:29637372</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637350/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637350'>PMID:29637350</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637355/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637355'>PMID:29637355</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637369/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637369'>PMID:29637369</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/29637368/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29637368'>PMID:29637368</a> and other 27.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 222 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/34362780/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34362780'>PMID:34362780</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34359080/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34359080'>PMID:34359080</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 180 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/30255464/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30255464'>PMID:30255464</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/30255389/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30255389'>PMID:30255389</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 86 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/34282481/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34282481'>PMID:34282481</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34076782/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34076782'>PMID:34076782</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34037807/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34037807'>PMID:34037807</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 109 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/29552348/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29552348'>PMID:29552348</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/29861556/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29861556'>PMID:29861556</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 108 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/32288974/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32288974'>PMID:32288974</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/18781266/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18781266'>PMID:18781266</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 91 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/21505933/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21505933'>PMID:21505933</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/28879382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28879382'>PMID:28879382</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 89 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/26697462/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26697462'>PMID:26697462</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/26716047/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26716047'>PMID:26716047</a>.</p></li>
# <li><p class="paragraph">Group with 4 nodes (degree 43 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/32734178/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32734178'>PMID:32734178</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/30758679/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30758679'>PMID:30758679</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/31019926/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:31019926'>PMID:31019926</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/30983746/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30983746'>PMID:30983746</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 86 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/34311518/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34311518'>PMID:34311518</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34305047/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34305047'>PMID:34305047</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 84 and unknown node type): <a href='https://pubmed.ncbi.nlm.nih.gov/32336937/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32336937'>PMID:32336937</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/32336936/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32336936'>PMID:32336936</a>.</p></li></ol><p class="paragraph">And other 2.00K isomorphic node groups.</p><h4 style="margin: 1em 0 0 0;">Trees</h4><p class="paragraph">A tree is a connected component with <code>n</code> nodes and <code>n-1</code> edges. We have detected 164 trees in the graph, involving a total of 1.13K nodes and 1.93K edges, with the largest one involving 66 nodes and 130 edges. The detected trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0500184' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500184'>HP:0500184</a> (degree 13), and containing 66 nodes, with a maximal depth of 3, which are <a href='http://purl.obolibrary.org/obo/HP_0500183' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500183'>HP:0500183</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0500185' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500185'>HP:0500185</a> (degree 4), <a href='http://purl.obolibrary.org/obo/HP_0500195' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500195'>HP:0500195</a> (degree 4), <a href='http://purl.obolibrary.org/obo/HP_0500205' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500205'>HP:0500205</a> (degree 5) and <a href='http://purl.obolibrary.org/obo/HP_0500214' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0500214'>HP:0500214</a> (degree 4). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/32874261/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874261'>PMID:32874261</a> (degree 2), and containing 18 nodes, with a maximal depth of 4, which are <a href='https://pubmed.ncbi.nlm.nih.gov/32695237/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32695237'>PMID:32695237</a> (degree 8), <a href='https://pubmed.ncbi.nlm.nih.gov/33082870/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33082870'>PMID:33082870</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32874258/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874258'>PMID:32874258</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32874262/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874262'>PMID:32874262</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/32874263/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32874263'>PMID:32874263</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13296855/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13296855'>PMID:13296855</a> (degree 3), and containing 17 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/13837688/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13837688'>PMID:13837688</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/14336746/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14336746'>PMID:14336746</a> (degree 9), <a href='https://pubmed.ncbi.nlm.nih.gov/5302972/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5302972'>PMID:5302972</a> (degree 5), <a href='https://pubmed.ncbi.nlm.nih.gov/13300581/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13300581'>PMID:13300581</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/12986493/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12986493'>PMID:12986493</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='http://purl.obolibrary.org/obo/PATO_0001404' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001404'>PATO:0001404</a> (degree 3), and containing 15 nodes, with a maximal depth of 4, which are <a href='http://purl.obolibrary.org/obo/PATO_0001396' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001396'>PATO:0001396</a> (degree 4), <a href='http://purl.obolibrary.org/obo/PATO_0001405' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001405'>PATO:0001405</a>, <a href='http://purl.obolibrary.org/obo/PATO_0002505' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0002505'>PATO:0002505</a> (degree 3), <a href='http://purl.obolibrary.org/obo/PATO_0001374' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001374'>PATO:0001374</a> and <a href='http://purl.obolibrary.org/obo/PATO_0001397' target='_blank' title='Go to Phenotype And Trait Ontology to get more informations about PATO:0001397'>PATO:0001397</a> (degree 4). Its nodes have 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/NamedThing.html' target='_blank' title='Go to BioLink to get more informations about biolink:NamedThing'>biolink:NamedThing</a> (14 nodes) and <a href='https://biolink.github.io/biolink-model/docs/OntologyClass.html' target='_blank' title='Go to BioLink to get more informations about biolink:OntologyClass'>biolink:OntologyClass</a> (14 nodes). Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/32695239/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32695239'>PMID:32695239</a> (degree 4), and containing 15 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/33082875/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33082875'>PMID:33082875</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/33235635/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33235635'>PMID:33235635</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34136007/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34136007'>PMID:34136007</a> (degree 11), <a href='https://pubmed.ncbi.nlm.nih.gov/34136009/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34136009'>PMID:34136009</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/34400975/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34400975'>PMID:34400975</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/9617072/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:9617072'>PMID:9617072</a> (degree 11), and containing 14 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/1130567/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1130567'>PMID:1130567</a> (degree 3), <a href='https://pubmed.ncbi.nlm.nih.gov/4509539/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:4509539'>PMID:4509539</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/5261552/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5261552'>PMID:5261552</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/5262521/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5262521'>PMID:5262521</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/5270724/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5270724'>PMID:5270724</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 158 trees.</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 5.63K dendritic trees in the graph, involving a total of 42.97K nodes (0.19%) and 85.94K edges (0.02%), with the largest one involving 2.92K nodes and 5.84K edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/18156677/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18156677'>PMID:18156677</a> (degree 28.17K), and containing 2.92K nodes, with a maximal depth of 3, which are <a href='https://pubmed.ncbi.nlm.nih.gov/20072813/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20072813'>PMID:20072813</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20203389/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20203389'>PMID:20203389</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/20203392/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:20203392'>PMID:20203392</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/21200980/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21200980'>PMID:21200980</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/21200982/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:21200982'>PMID:21200982</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/7469924/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7469924'>PMID:7469924</a> (degree 623), and containing 243 nodes, with a maximal depth of 3, which are <a href='https://pubmed.ncbi.nlm.nih.gov/1002068/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1002068'>PMID:1002068</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/1005973/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1005973'>PMID:1005973</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/1016456/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1016456'>PMID:1016456</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/1029713/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1029713'>PMID:1029713</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/1029715/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:1029715'>PMID:1029715</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/13219341/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13219341'>PMID:13219341</a> (degree 559), and containing 234 nodes, with a maximal depth of 4, which are <a href='https://pubmed.ncbi.nlm.nih.gov/12975866/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12975866'>PMID:12975866</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976390/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976390'>PMID:12976390</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976773/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976773'>PMID:12976773</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/12976907/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12976907'>PMID:12976907</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/12978282/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:12978282'>PMID:12978282</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='http://purl.obolibrary.org/obo/HP_0000118' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000118'>HP:0000118</a> (degree 24), and containing 221 nodes, with a maximal depth of 7, which are <a href='http://purl.obolibrary.org/obo/HP_0000001' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000001'>HP:0000001</a> (degree 6), <a href='http://purl.obolibrary.org/obo/HP_0000005' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0000005'>HP:0000005</a> (degree 3), <a href='http://purl.obolibrary.org/obo/HP_0012823' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0012823'>HP:0012823</a> (degree 13), <a href='http://purl.obolibrary.org/obo/HP_0032223' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032223'>HP:0032223</a> (degree 3) and <a href='http://purl.obolibrary.org/obo/HP_0032443' target='_blank' title='Go to Human Phenotype Ontology to get more informations about HP:0032443'>HP:0032443</a> (degree 9). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/PhenotypicFeature.html' target='_blank' title='Go to BioLink to get more informations about biolink:PhenotypicFeature'>biolink:PhenotypicFeature</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/25972760/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:25972760'>PMID:25972760</a> (degree 405), and containing 180 nodes, with a maximal depth of 5, which are <a href='https://pubmed.ncbi.nlm.nih.gov/10012062/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10012062'>PMID:10012062</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/10012211/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10012211'>PMID:10012211</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/10016451/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10016451'>PMID:10016451</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/10016769/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10016769'>PMID:10016769</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/10016928/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:10016928'>PMID:10016928</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# ...
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/5469766/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5469766'>PMID:5469766</a> (degree 5), and containing 7 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/13001212/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13001212'>PMID:13001212</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13113765/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13113765'>PMID:13113765</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13407857/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13407857'>PMID:13407857</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13690953/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13690953'>PMID:13690953</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/14060438/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14060438'>PMID:14060438</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/5213250/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:5213250'>PMID:5213250</a> (degree 5), and containing 7 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/14081382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14081382'>PMID:14081382</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/14142747/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14142747'>PMID:14142747</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/14213783/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14213783'>PMID:14213783</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/14268325/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14268325'>PMID:14268325</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/18141122/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18141122'>PMID:18141122</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/14188316/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:14188316'>PMID:14188316</a> (degree 4), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/13080382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13080382'>PMID:13080382</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13436734/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13436734'>PMID:13436734</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/13832789/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:13832789'>PMID:13832789</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/18170601/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18170601'>PMID:18170601</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/18170399/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:18170399'>PMID:18170399</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Free-floating chain starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/29170609/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:29170609'>PMID:29170609</a> (degree 4), and containing 6 nodes, with a maximal depth of 2, which are <a href='https://pubmed.ncbi.nlm.nih.gov/24719584/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24719584'>PMID:24719584</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/24808309/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24808309'>PMID:24808309</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/24808314/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:24808314'>PMID:24808314</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28163545/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28163545'>PMID:28163545</a> (degree 3) and <a href='https://pubmed.ncbi.nlm.nih.gov/30839906/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:30839906'>PMID:30839906</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 217 free-floating chains.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 1.25M tendrils in the graph, involving a total of 1.26M nodes (5.68%) and 2.52M edges (0.51%), with the largest one involving 9 nodes and 18 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1206794' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1206794'>NCBITaxon:1206794</a> (degree 3), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6231' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6231'>NCBITaxon:6231</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=119089' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:119089'>NCBITaxon:119089</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=6236' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:6236'>NCBITaxon:6236</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301116' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301116'>NCBITaxon:2301116</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=2301119' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:2301119'>NCBITaxon:2301119</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314146' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314146'>NCBITaxon:314146</a> (degree 4), and containing 9 nodes, with a maximal depth of 9, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314147' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314147'>NCBITaxon:314147</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9989' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9989'>NCBITaxon:9989</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1963758' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1963758'>NCBITaxon:1963758</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=337687' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:337687'>NCBITaxon:337687</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=10066' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:10066'>NCBITaxon:10066</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9443' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9443'>NCBITaxon:9443</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=376913' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:376913'>NCBITaxon:376913</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314293' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314293'>NCBITaxon:314293</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9526' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9526'>NCBITaxon:9526</a> (degree 3), <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=314295' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:314295'>NCBITaxon:314295</a> (degree 3) and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=9604' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:9604'>NCBITaxon:9604</a> (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a> (15 edges, 65.22%) and <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (8 edges, 34.78%).</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8457' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8457'>NCBITaxon:8457</a> (degree 4), and containing 8 nodes, with a maximal depth of 8, which are <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=32561' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:32561'>NCBITaxon:32561</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=1329799' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:1329799'>NCBITaxon:1329799</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=8492' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:8492'>NCBITaxon:8492</a>, <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=436486' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:436486'>NCBITaxon:436486</a> and <a href='https://www.ncbi.nlm.nih.gov/taxonomy/?term=436489' target='_blank' title='Go to NCBI Taxonomy to get more informations about NCBITaxon:436489'>NCBITaxon:436489</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismalEntity'>biolink:OrganismalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/2316051/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:2316051'>PMID:2316051</a> (degree 9), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://pubmed.ncbi.nlm.nih.gov/3122440/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:3122440'>PMID:3122440</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/3218382/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:3218382'>PMID:3218382</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/7423666/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7423666'>PMID:7423666</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/7071997/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:7071997'>PMID:7071997</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/835200/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:835200'>PMID:835200</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://pubmed.ncbi.nlm.nih.gov/27131647/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:27131647'>PMID:27131647</a> (degree 10), and containing 6 nodes, with a maximal depth of 6, which are <a href='https://pubmed.ncbi.nlm.nih.gov/33053833/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:33053833'>PMID:33053833</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/34067247/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:34067247'>PMID:34067247</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/32033246/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:32033246'>PMID:32033246</a>, <a href='https://pubmed.ncbi.nlm.nih.gov/28672830/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:28672830'>PMID:28672830</a> and <a href='https://pubmed.ncbi.nlm.nih.gov/26927117/' target='_blank' title='Go to Pubmed NCBI to get more informations about PMID:26927117'>PMID:26927117</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/Mentions.html' target='_blank' title='Go to BioLink to get more informations about biolink:Mentions'>biolink:Mentions</a>.</p></li></ol><p class="paragraph">And other 1.25M tendrils.</p></div>

# %% [markdown]
# ### Testing the validity of edge holdouts
# In this section, we will be testing the validity of our edge holdouts. Edge holdouts are a common method used in machine learning to evaluate the performance of a model. The goal is to ensure that the training and test sets do not share any edges, as this would compromise the validity of the evaluation. To test the validity of our holdouts, we will use various methods to check if the training and test sets overlap, and if they do, we will investigate the cause. We will also subtract the test set from the complete graph and verify that it is a valid holdout.

# %% [markdown]
# First, we create an edge holdout. In this instance, we are using a connected holdout. [You can learn more about holdouts in this previous tutorial.](https://github.com/AnacletoLAB/grape/blob/main/tutorials/Graph_holdouts_using_GRAPE.ipynb)

# %%
train, test = homo_sapiens.connected_holdout(train_size=0.8)

# %% [markdown]
# By definition, training and test holdouts SHOULD NOT share edges. We can trivially test this by making sure that the insection is empty:

# %%
train & test
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>(HomoSapiens train & HomoSapiens test)</h2><p class="paragraph">The graph (HomoSapiens train & HomoSapiens test) contains 19.57K heterogeneous nodes and no edges. If this is unexpected, it may have happened because of a mis-parametrization of a filter method uphill.</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 62.23K node types, of which the 10 most common are GO:0110165 (17.79K nodes, 90.91%), GO:0009987 (15.02K nodes, 76.79%), BTO:0000000 (14.94K nodes, 76.37%), BTO:0000042 (14.89K nodes, 76.13%), GO:0005622 (14.28K nodes, 72.96%), GOCC:0110165 (13.85K nodes, 70.80%), GO:0043226 (13.52K nodes, 69.07%), BTO:0001489 (12.62K nodes, 64.49%), GO:0043229 (12.53K nodes, 64.03%) and GO:0005488 (12.52K nodes, 63.97%). The node types are multi-label, and the node with most node types has 1379 node types. The RAM requirement for the node types data structure is 19.13MB.</p><h4 style="margin: 1em 0 0 0;">Approximated isomorphic node types</h4><p class="paragraph">Approximated isomorphic node types groups are node types describing exactly the same set of nodes. Since the graph has a high number of node types (> 50.00K) we use an approximated version of the node types isomorphisms detection. Note that hash collisions and false positives are possible. It is possible to execute the exact computation with the <code>get_isomorphic_node_type_ids_groups</code> method. The presence of such duplicated node types suggests a potential modelling error in the pipeline that has produced this graph. 9.34K isomorphic node types groups were detected in this graph.</p><ol><li><p class="paragraph">Isomorphic node type group containing 3 node types (5.86K nodes, 29.93%), which are: GO:0031974, GO:0043233 and GO:0070013.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (3.06K nodes, 15.65%), which are: GO:0006464 and GO:0036211.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (2.82K nodes, 14.39%), which are: GOCC:0031974 and GOCC:0043233.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.45K nodes, 7.43%), which are: GO:0038023 and GO:0060089.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.21K nodes, 6.20%), which are: GO:0031967 and GO:0031975.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.16K nodes, 5.95%), which are: GO:0010562 and GO:0045937.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.02K nodes, 5.20%), which are: GO:0048870 and GO:0051674.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (814 nodes, 4.16%), which are: GO:0016817 and GO:0016818.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (698 nodes, 3.57%), which are: GO:0000323 and GO:0005764.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (648 nodes, 3.31%), which are: BTO:0000775 and BTO:0001096.</p></li></ol><p class="paragraph">And other 9.33K isomorphic node types.</p><h4 style="margin: 1em 0 0 0;">Singleton node types</h4><p class="paragraph">Singleton node types are node types that are assigned exclusively to a single node, making the node type relatively meaningless, as it adds no more information than the node name itself. The graph contains 16.85K singleton node types, which are IPR028927 (9606.ENSP00000000412 (node types BTO:0000000, BTO:0000042, BTO:0000080, BTO:0000081, BTO:0000082 and other 188)), GO:0006463 (9606.ENSP00000001008 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR031212 (9606.ENSP00000001008 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR003788 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), IPR038375 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), PF02636 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), BTO:0001193 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002032 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002750 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)) and BTO:0004445 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), plus other 16.84K singleton node types.</p><h4 style="margin: 1em 0 0 0;">Unknown node types</h4><p class="paragraph">Nodes with unknown node types are nodes with a node type that was not provided during the creation of the graph, which may be desired as the output of a node-label holdout. The graph contains 159 nodes with unknown node type, which are 9606.ENSP00000239125, 9606.ENSP00000278779, 9606.ENSP00000303234, 9606.ENSP00000326574, 9606.ENSP00000362001, 9606.ENSP00000365108, 9606.ENSP00000366765, 9606.ENSP00000367360, 9606.ENSP00000367983 and 9606.ENSP00000368055, plus other 149 nodes with unknown node types, making up 0.81 of the nodes.</p></div>

# %% [markdown]
# We can verify this also easily using:

# %%
train.overlaps(test), test.overlaps(train)
# Out:
# (False, False)

# %% [markdown]
# We can also subtract the test set to the complete graph, and run the same test:

# %%
test.overlaps(homo_sapiens - test), test.overlaps(homo_sapiens)
# Out:
# (False, True)

# %% [markdown]
# And if we subtract train and test to the complete graph, we should get an empty graph:

# %%
homo_sapiens - train - test
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>((HomoSapiens - HomoSapiens train) - HomoSapiens test)</h2><p class="paragraph">The graph ((HomoSapiens - HomoSapiens train) - HomoSapiens test) contains 19.57K heterogeneous nodes and no edges. If this is unexpected, it may have happened because of a mis-parametrization of a filter method uphill.</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 62.23K node types, of which the 10 most common are GO:0110165 (17.79K nodes, 90.91%), GO:0009987 (15.02K nodes, 76.79%), BTO:0000000 (14.94K nodes, 76.37%), BTO:0000042 (14.89K nodes, 76.13%), GO:0005622 (14.28K nodes, 72.96%), GOCC:0110165 (13.85K nodes, 70.80%), GO:0043226 (13.52K nodes, 69.07%), BTO:0001489 (12.62K nodes, 64.49%), GO:0043229 (12.53K nodes, 64.03%) and GO:0005488 (12.52K nodes, 63.97%). The node types are multi-label, and the node with most node types has 1379 node types. The RAM requirement for the node types data structure is 19.13MB.</p><h4 style="margin: 1em 0 0 0;">Approximated isomorphic node types</h4><p class="paragraph">Approximated isomorphic node types groups are node types describing exactly the same set of nodes. Since the graph has a high number of node types (> 50.00K) we use an approximated version of the node types isomorphisms detection. Note that hash collisions and false positives are possible. It is possible to execute the exact computation with the <code>get_isomorphic_node_type_ids_groups</code> method. The presence of such duplicated node types suggests a potential modelling error in the pipeline that has produced this graph. 9.34K isomorphic node types groups were detected in this graph.</p><ol><li><p class="paragraph">Isomorphic node type group containing 3 node types (5.86K nodes, 29.93%), which are: GO:0031974, GO:0043233 and GO:0070013.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (3.06K nodes, 15.65%), which are: GO:0006464 and GO:0036211.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (2.82K nodes, 14.39%), which are: GOCC:0031974 and GOCC:0043233.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.45K nodes, 7.43%), which are: GO:0038023 and GO:0060089.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.21K nodes, 6.20%), which are: GO:0031967 and GO:0031975.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.16K nodes, 5.95%), which are: GO:0010562 and GO:0045937.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (1.02K nodes, 5.20%), which are: GO:0048870 and GO:0051674.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (814 nodes, 4.16%), which are: GO:0016817 and GO:0016818.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (698 nodes, 3.57%), which are: GO:0000323 and GO:0005764.</p></li>
# <li><p class="paragraph">Isomorphic node type group containing 2 node types (648 nodes, 3.31%), which are: BTO:0000775 and BTO:0001096.</p></li></ol><p class="paragraph">And other 9.33K isomorphic node types.</p><h4 style="margin: 1em 0 0 0;">Singleton node types</h4><p class="paragraph">Singleton node types are node types that are assigned exclusively to a single node, making the node type relatively meaningless, as it adds no more information than the node name itself. The graph contains 16.85K singleton node types, which are IPR028927 (9606.ENSP00000000412 (node types BTO:0000000, BTO:0000042, BTO:0000080, BTO:0000081, BTO:0000082 and other 188)), GO:0006463 (9606.ENSP00000001008 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR031212 (9606.ENSP00000001008 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000089 and other 332)), IPR003788 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), IPR038375 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), PF02636 (9606.ENSP00000002125 (node types BTO:0000000, BTO:0000042, BTO:0000081, BTO:0000083, BTO:0000176 and other 115)), BTO:0001193 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002032 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), BTO:0002750 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)) and BTO:0004445 (9606.ENSP00000003084 (node types BTO:0000000, BTO:0000003, BTO:0000042, BTO:0000081, BTO:0000082 and other 558)), plus other 16.84K singleton node types.</p><h4 style="margin: 1em 0 0 0;">Unknown node types</h4><p class="paragraph">Nodes with unknown node types are nodes with a node type that was not provided during the creation of the graph, which may be desired as the output of a node-label holdout. The graph contains 159 nodes with unknown node type, which are 9606.ENSP00000239125, 9606.ENSP00000278779, 9606.ENSP00000303234, 9606.ENSP00000326574, 9606.ENSP00000362001, 9606.ENSP00000365108, 9606.ENSP00000366765, 9606.ENSP00000367360, 9606.ENSP00000367983 and 9606.ENSP00000368055, plus other 149 nodes with unknown node types, making up 0.81 of the nodes.</p></div>

# %% [markdown]
# ## Conclusions
# In this tutorial, we explored the use of set theory and set algebra in the context of graphs and graph analysis. We learned about various set theory operations that can be applied to graphs, including union, intersection, and difference. These operations allow us to manipulate and analyze graphs in a more formal and precise way, and they are an important part of the mathematical language used to describe and reason about graphs.
#
# We also saw how these operations can be used to merge and compare different graphs, such as ontologies and knowledge graphs, in order to extract and analyze the relevant information contained within them.
#
# Finally, we learned how to test the validity of edge holdouts using set theory operations. Overall, this tutorial provided an introduction to the use of set theory and set algebra in the context of graph analysis and machine learning, and it demonstrated the power and utility of these concepts for understanding and analyzing complex systems and relationships.
#
# I hope you now understand the applications and benefits of graph set algebra and how to use [GRAPE](https://github.com/AnacletoLAB/grape) to use it for your projects. Do feel free to reach out with any questions or feedback, as I always look for ways to improve this tutorial.
#
# [And remember to ⭐ GRAPE!](https://github.com/AnacletoLAB/grape)
